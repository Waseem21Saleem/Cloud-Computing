# %% [markdown]
# <a href="https://colab.research.google.com/github/Waseem21Saleem/Cloud-Computing/blob/main/Homework/HW2/hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase
# !pip install firebase-admin ipywidgets plotly pandas
#!pip install --upgrade plotly
# !pip install reportlab
# Out:
# Collecting firebase
#   Downloading firebase-4.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from firebase) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2024.7.4)
# Downloading firebase-4.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: firebase
# Successfully installed firebase-4.0.1
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: cachecontrol>=0.12.6 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (0.14.0)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.137.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.8.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.19.1)
# Requirement already satisfied: google-cloud-firestore>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.16.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.7)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase-admin) (2.31.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase-admin) (1.0.8)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.24.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.27.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.48.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-firestore>=2.1.0->firebase-admin) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (71.0.4)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage>=1.37.1->firebase-admin) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2024.7.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.19.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.2)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1
# Collecting reportlab
#   Downloading reportlab-4.2.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (9.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Downloading reportlab-4.2.2-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.8 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.2.2

# %%
import firebase_admin
from firebase_admin import credentials, db
import ipywidgets as widgets
from IPython.display import display, HTML
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import io
import base64
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.utils import ImageReader


matplotlib.use('Agg')  # Use a non-interactive backend for matplotlib

# Initialize Firebase app with JSON contents
def init_firebase(json_contents):
    try:
        firebase_admin.get_app()
    except ValueError:
        cred = credentials.Certificate(json_contents)
        firebase_admin.initialize_app(cred, {
            'databaseURL': 'https://phoenixes-34c33-default-rtdb.europe-west1.firebasedatabase.app/'
        })

# Fetch data from Firebase
def fetch_data():
    ref = db.reference('/')
    data = ref.get()
    if not data:
        raise ValueError("No data found in the Firebase database.")
    return data

# Process data
def process_data(data):
    relevant_actions = []
    for entry in data:
        description = entry.get('Description', '')
        if 'opened by' in description or 'Change Element Timings Event' in description:
            relevant_actions.append(entry)
    if not relevant_actions:
        raise ValueError("No relevant actions found in the data.")
    df = pd.DataFrame(relevant_actions)
    df['Time'] = pd.to_datetime(df['Time'])
    return df

# Functions for data processing and visualization
def filter_data_by_date(df, date):
    if date:
        date_str = date.strftime('%Y-%m-%d')
        filtered_df = df[df['Time'].dt.strftime('%Y-%m-%d') == date_str]
        return filtered_df
    return df

def filter_data_by_month(df, month):
    if month:
        month_str = month.strftime('%Y-%m')
        filtered_df = df[df['Time'].dt.strftime('%Y-%m') == month_str]
        return filtered_df
    return df

def calculate_progress_percentage(filtered_df):
    student_actions = filtered_df['User'].value_counts()
    total_actions = student_actions.sum()
    progress_percentage = (student_actions / total_actions) * 100
    return progress_percentage

def create_student_progress_charts(filtered_df):
    progress_percentage = calculate_progress_percentage(filtered_df)
    figures = []
    for student, percentage in progress_percentage.items():
        student_df = filtered_df[filtered_df['User'] == student]
        progress_counts = student_df['Description'].value_counts()
        fig, ax = plt.subplots(figsize=(10, 6))  # Adjust size for better readability
        ax.barh(progress_counts.index, progress_counts.values, color='skyblue')
        ax.set_title(f"Progress for {student} ({percentage:.2f}%)")
        ax.set_xlabel("Count")
        ax.set_ylabel("Actions")
        plt.tight_layout()
        figures.append(fig)
    return figures

def create_monthly_summary_chart(filtered_df):
    progress_percentage = calculate_progress_percentage(filtered_df)
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(progress_percentage.index, progress_percentage.values, color='skyblue')

    # Adding percentage labels above bars
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}%', va='bottom')  # va: vertical alignment

    ax.set_title("Monthly Summary")
    ax.set_xlabel("Students")
    ax.set_ylabel("Progress Percentage")
    plt.tight_layout()
    return fig

def find_top_performer(filtered_df):
    progress_percentage = calculate_progress_percentage(filtered_df)
    top_student = progress_percentage.idxmax()
    top_percentage = progress_percentage.max()
    return top_student, top_percentage

def generate_report(student_name, from_date, to_date):
    # Convert date strings to datetime objects
    from_date = pd.to_datetime(from_date)
    to_date = pd.to_datetime(to_date)

    # Filter data for the specified student and date range
    student_df = df[(df['User'] == student_name) & (df['Time'] >= from_date) & (df['Time'] <= to_date)]

    # Create a PDF buffer
    pdf_buffer = io.BytesIO()
    c = canvas.Canvas(pdf_buffer, pagesize=letter)

    # Add a centered title
    c.setFont("Helvetica-Bold", 18)
    c.drawCentredString(300, 750, "Performance Report")

    # Add student name and date range information in bold
    c.setFont("Helvetica-Bold", 12)
    c.drawString(100, 700, f"Student Name: {student_name}")
    c.drawString(100, 680, f"From Date: {from_date.strftime('%Y-%m-%d')}")
    c.drawString(100, 660, f"To Date: {to_date.strftime('%Y-%m-%d')}")
    c.setFont("Helvetica", 12)
    c.drawString(100, 640, "Generated using the Student Progress Dashboard.")

    # Add a summary of actions
    if not student_df.empty:
        c.setFont("Helvetica-Bold", 12)
        c.drawString(100, 620, "Summary of Actions:")
        c.setFont("Helvetica", 12)
        action_counts = student_df['Description'].value_counts()
        y_position = 600
        for action, count in action_counts.items():
            c.drawString(100, y_position, f"{action}: {count} times")
            y_position -= 20
            if y_position < 50:
                c.showPage()
                y_position = 750
    else:
        c.drawString(100, 620, "No actions found for the specified date range.")

    # Save and close the PDF
    c.showPage()
    c.save()

    # Get the PDF data
    pdf_buffer.seek(0)
    pdf_bytes = pdf_buffer.read()

    # Encode the PDF in base64
    b64_pdf = base64.b64encode(pdf_bytes).decode('utf-8')

    return b64_pdf


# Register the callback
#output.register_callback('generateReport', generate_report)



def fig_to_html(fig):
    buf = io.BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    img_str = base64.b64encode(buf.read()).decode('utf-8')
    return f'<img src="data:image/png;base64,{img_str}" class="chart" />'

# Callback function to update the GUI
def update_gui(tab, date):
    global df  # Use the global dataframe
    output_html = ""

    if tab == 'Overall Progress':
        filtered_df = filter_data_by_date(df, pd.to_datetime(date))
        if filtered_df.empty:
            output_html = "<h3>No data available for the selected date.</h3>"
        else:
            progress_percentage = calculate_progress_percentage(filtered_df)
            output_html += "<h3>Overall Progress Percentage</h3><p>This chart shows the percentage of actions taken by each student out of the total actions recorded on the selected date.</p>"
            fig, ax = plt.subplots()
            ax.bar(progress_percentage.index, progress_percentage.values)
            ax.set_title("Overall Progress Percentage")
            ax.set_xlabel("Students")
            ax.set_ylabel("Progress Percentage")
            plt.tight_layout()
            output_html += fig_to_html(fig)
            plt.close(fig)

    elif tab == 'Individual Progress':
        filtered_df = filter_data_by_date(df, pd.to_datetime(date))
        if filtered_df.empty:
            output_html = "<h3>No individual progress data available.</h3>"
        else:
            figures = create_student_progress_charts(filtered_df)
            output_html += "<h3>Individual Progress</h3><p>These charts show the breakdown of actions taken by each student on the selected date, along with the percentage of their contribution to the total actions.</p>"
            for fig in figures:
                output_html += fig_to_html(fig)
                plt.close(fig)

    elif tab == 'Top Performer':
        filtered_df = filter_data_by_date(df, pd.to_datetime(date))
        if filtered_df.empty:
            output_html = "<h3>No data available for the selected date.</h3>"
        else:
            top_student, top_percentage = find_top_performer(filtered_df)
            output_html = f"<h3>Top Performer</h3><p>The top performer for the selected date is {top_student}, with {top_percentage:.2f}% of the total actions.</p>"

    elif tab == 'Monthly Summary':
        filtered_df = filter_data_by_month(df, pd.to_datetime(date))
        if filtered_df.empty:
            output_html = "<h3>No data available for the selected month.</h3>"
        else:
            fig = create_monthly_summary_chart(filtered_df)
            output_html += "<h3>Monthly Summary</h3><p>This chart shows the overall progress percentage for each student for the selected month.</p>"
            output_html += fig_to_html(fig)
            plt.close(fig)

    # Update the output div with the result
    display(HTML(f"<script>document.getElementById('output').innerHTML = `{output_html}`;</script>"))

# Callback function to search the database
def search_database(student_name, date, tab, document, description, keyword):
    global df
    search_conditions = []
    if student_name:
        search_conditions.append(df['User'].str.contains(student_name, case=False, na=False))
    if date:
        search_conditions.append(df['Time'].dt.strftime('%Y-%m-%d') == date)
    if tab:
        search_conditions.append(df['Tab'].str.contains(tab, case=False, na=False))
    if document:
        search_conditions.append(df['Document'].str.contains(document, case=False, na=False))
    if description:
        search_conditions.append(df['Description'].str.contains(description, case=False, na=False))
    if keyword:
        keyword_condition = df.apply(lambda row: row.astype(str).str.contains(keyword, case=False).any(), axis=1)
        search_conditions.append(keyword_condition)

    if search_conditions:
        result_df = df[search_conditions[0]]
        for condition in search_conditions[1:]:
            result_df = result_df[condition]
    else:
        result_df = df

    if result_df.empty:
        output_html = "<h3>No results found for the given criteria.</h3>"
    else:
        output_html = result_df.to_html(classes='search-results', index=False)
    display(HTML(f"<script>document.getElementById('search-output').innerHTML = `{output_html}`;</script>"))

# Define JavaScript to Python interaction
from google.colab import output
output.register_callback('updateData', update_gui)
output.register_callback('searchDatabase', search_database)
output.register_callback('initFirebase', init_firebase)
output.register_callback('generateReport', generate_report)


# Create widgets for the dashboard
tab_selector = widgets.Dropdown(
    options=['Overall Progress', 'Individual Progress', 'Top Performer', 'Monthly Summary'],
    value='Overall Progress',
    description='Select Tab:',
    style={'description_width': 'initial'}
)

date_picker = widgets.DatePicker(
    description='Select Date',
    disabled=False,
    style={'description_width': 'initial'}
)

update_button = widgets.Button(
    description='Show results',
    button_style='success',
    style={'description_width': 'initial'}
)

# HTML layout
html = """
<style>
    body { font-family: Arial, sans-serif; }
    .container { width: 80%; margin: 0 auto; }
    .header { text-align: center; margin-bottom: 20px; position: relative; }
    .form-group { margin-bottom: 20px; }
    .form-group label { display: block; margin-bottom: 5px; }
    .form-group select, .form-group input { width: 100%; padding: 8px; }
    .charts { margin-top: 20px; }
    .chart { margin-bottom: 20px; }
    .upload-container { position: absolute; top: 10px; right: 10px; text-align: right; }
    .upload-container small { display: block; margin-bottom: 5px; }
    .upload-btn { display: inline-block; }
    .search-container { text-align: left; margin-bottom: 20px; }
    .search-btn, .back-btn, .report-gui-btn, .make-report-btn { display: inline-block; margin-bottom: 10px; }
    .back-btn, .search-indexbtn { position: absolute; top: 10px; left: 10px; }
    .report-gui-btn { position: absolute; top: 10px; left: 140px; }
    .search-output { margin-top: 20px; }
    .search-results { width: 100%; border-collapse: collapse; }
    .search-results th, .search-results td { border: 1px solid #ddd; padding: 8px; }
    .search-results th { background-color: #f2f2f2; cursor: pointer; }
    .modal { display: none; position: fixed; z-index: 1; left: 0; top: 0; width: 100%; height: 100%; overflow: auto; background-color: rgb(0,0,0); background-color: rgba(0,0,0,0.4); }
    .modal-content { background-color: #fefefe; margin: 15% auto; padding: 20px; border: 1px solid #888; width: 80%; }
    .centered { text-align: center; }
</style>

<div class="container" id="main-gui">
    <div class="header">
        <h1>Student Progress Dashboard</h1>
        <button id="search-button" class="search-indexbtn">Search Database</button>
        <button id="report-button" class="report-gui-btn">Create Report</button>
        <div class="upload-container">
            <small>Upload credentials.json</small>
            <input type="file" id="firebase-upload" accept=".json" class="upload-btn" title="Upload Credentials" />
        </div>
        <div class="form-group">
            <label for="tab-selector">Select Tab:</label>
            <select id="tab-selector">
                <option value="Overall Progress">Overall Progress</option>
                <option value="Individual Progress">Individual Progress</option>
                <option value="Top Performer">Top Performer</option>
                <option value="Monthly Summary">Monthly Summary</option>
            </select>
        </div>
        <div class="form-group">
            <label for="date-picker">Select Date:</label>
            <input type="date" id="date-picker">
        </div>
        <button id="update-button" class="search-btn">Show results</button>
    </div>
    <div id="output" class="charts"></div>
</div>

<div class="container" id="search-gui" style="display: none;">
    <div class="header">
        <h1>Search Database</h1>
        <div class="form-group">
            <label for="student-name">Student Name:</label>
            <input type="text" id="student-name">
        </div>
        <div class="form-group">
            <label for="search-date-picker">Select Date:</label>
            <input type="date" id="search-date-picker">
        </div>
        <div class="form-group">
            <label for="tab">Tab:</label>
            <input type="text" id="tab">
        </div>
        <div class="form-group">
            <label for="document">Document:</label>
            <input type="text" id="document">
        </div>
        <div class="form-group">
            <label for="description">Description:</label>
            <input type="text" id="description">
        </div>
        <div class="form-group">
            <label for="keyword">Keyword:</label>
            <input type="text" id="keyword">
        </div>
        <div class="centered">
            <button id="search-submit-button" class="search-btn">Search</button>
        </div>
        <div class="upload-container">
            <small>Upload credentials.json</small>
            <input type="file" id="firebase-upload-search" accept=".json" class="upload-btn" title="Upload Credentials" />
        </div>
        <div>
            <button id="back-button" class="back-btn">Back to Main</button>
        </div>
    </div>
    <div id="search-output" class="search-output"></div>
</div>
<div class="container" id="report-gui" style="display: none;">
    <div class="header">
        <h1>Student Performance Report</h1>
        <div class="form-group">
            <label for="student_name">Student Name:</label>
            <input type="text" id="student_name">
        </div>
        <div class="form-group">
            <label for="from_date">From Date:</label>
            <input type="date" id="from_date">
        </div>
        <div class="form-group">
            <label for="to_date">To Date:</label>
            <input type="date" id="to_date">
        </div>
        <div class="centered">
            <button id="make-report-button" class="make-report-btn">Generate Report</button>
        </div>

        <div>
            <button id="back-button2" class="back-btn">Back to Main</button>
        </div>
    </div>
    <div id="search-output" class="search-output"></div>
</div>
<div id="modal" class="modal">
    <div class="modal-content">
        <p id="modal-message"></p>
        <button id="close-modal" class="centered">Close</button>
    </div>
</div>
"""

display(HTML(html))

# JavaScript to handle button clicks and update the GUI
js_code = """
<script>
document.getElementById('update-button').addEventListener('click', () => {
    const tab = document.getElementById('tab-selector').value;
    const date = document.getElementById('date-picker').value;
    google.colab.kernel.invokeFunction('updateData', [tab, date], {});
});

document.getElementById('search-button').addEventListener('click', () => {
    document.getElementById('main-gui').style.display = 'none';
    document.getElementById('search-gui').style.display = 'block';
});

document.getElementById('report-button').addEventListener('click', () => {
    document.getElementById('main-gui').style.display = 'none';
    document.getElementById('report-gui').style.display = 'block';
});

document.getElementById('back-button').addEventListener('click', () => {
    document.getElementById('main-gui').style.display = 'block';
    document.getElementById('search-gui').style.display = 'none';
});

document.getElementById('back-button2').addEventListener('click', () => {
    document.getElementById('main-gui').style.display = 'block';
    document.getElementById('report-gui').style.display = 'none';
});

document.getElementById('search-submit-button').addEventListener('click', () => {
    const studentName = document.getElementById('student-name').value;
    const date = document.getElementById('search-date-picker').value;
    const tab = document.getElementById('tab').value;
    const documentText = document.getElementById('document').value;
    const description = document.getElementById('description').value;
    const keyword = document.getElementById('keyword').value;
    google.colab.kernel.invokeFunction('searchDatabase', [studentName, date, tab, documentText, description, keyword], {});
});

document.getElementById('make-report-button').addEventListener('click', () => {
    const studentName = document.getElementById('student_name').value;
    const fromDate = document.getElementById('from_date').value;
    const toDate = document.getElementById('to_date').value;

    google.colab.kernel.invokeFunction('generateReport', [studentName, fromDate, toDate], {}).then(result => {
        let b64_pdf = result.data['text/plain'];
        b64_pdf = b64_pdf.replace(/^'|'$/g, ''); // Remove leading and trailing single quotes if present
        if (b64_pdf) {
            const link = document.createElement('a');
            link.href = `data:application/pdf;base64,${b64_pdf}`;
            link.download = `${studentName}-${fromDate}-${toDate}.pdf`; // Change the filename here
            document.body.appendChild(link);
            link.click();
            document.body.removeChild(link);
        } else {
            alert("Failed to generate the report. Please try again.");
        }
    });
});






function handleFileUpload(event) {
    const file = event.target.files[0];
    const reader = new FileReader();
    reader.onload = function(e) {
        const contents = e.target.result;
        try {
            const jsonContents = JSON.parse(contents);
            google.colab.kernel.invokeFunction('initFirebase', [jsonContents], {});
            showModal('Credentials file uploaded successfully.');
        } catch (error) {
            showModal('Invalid JSON file.');
        }
    };
    reader.readAsText(file);
}

document.getElementById('firebase-upload').addEventListener('change', handleFileUpload);

document.getElementById('firebase-upload-search').addEventListener('change', handleFileUpload);

document.getElementById('close-modal').addEventListener('click', () => {
    document.getElementById('modal').style.display = 'none';
});

function showModal(message) {
    document.getElementById('modal-message').innerText = message;
    document.getElementById('modal').style.display = 'block';
}
</script>
"""

display(HTML(js_code))

# Load initial data from Firebase
try:
    data = fetch_data()
    df = process_data(data)
except Exception as e:
    display(HTML(f'<p style="color: red;">Error loading data: {str(e)}</p>'))
# Out:
# <style>
#     body { font-family: Arial, sans-serif; }
#     .container { width: 80%; margin: 0 auto; }
#     .header { text-align: center; margin-bottom: 20px; position: relative; }
#     .form-group { margin-bottom: 20px; }
#     .form-group label { display: block; margin-bottom: 5px; }
#     .form-group select, .form-group input { width: 100%; padding: 8px; }
#     .charts { margin-top: 20px; }
#     .chart { margin-bottom: 20px; }
#     .upload-container { position: absolute; top: 10px; right: 10px; text-align: right; }
#     .upload-container small { display: block; margin-bottom: 5px; }
#     .upload-btn { display: inline-block; }
#     .search-container { text-align: left; margin-bottom: 20px; }
#     .search-btn, .back-btn, .report-gui-btn, .make-report-btn { display: inline-block; margin-bottom: 10px; }
#     .back-btn, .search-indexbtn { position: absolute; top: 10px; left: 10px; }
#     .report-gui-btn { position: absolute; top: 10px; left: 140px; }
#     .search-output { margin-top: 20px; }
#     .search-results { width: 100%; border-collapse: collapse; }
#     .search-results th, .search-results td { border: 1px solid #ddd; padding: 8px; }
#     .search-results th { background-color: #f2f2f2; cursor: pointer; }
#     .modal { display: none; position: fixed; z-index: 1; left: 0; top: 0; width: 100%; height: 100%; overflow: auto; background-color: rgb(0,0,0); background-color: rgba(0,0,0,0.4); }
#     .modal-content { background-color: #fefefe; margin: 15% auto; padding: 20px; border: 1px solid #888; width: 80%; }
#     .centered { text-align: center; }
# </style>
#
# <div class="container" id="main-gui">
#     <div class="header">
#         <h1>Student Progress Dashboard</h1>
#         <button id="search-button" class="search-indexbtn">Search Database</button>
#         <button id="report-button" class="report-gui-btn">Create Report</button>
#         <div class="upload-container">
#             <small>Upload credentials.json</small>
#             <input type="file" id="firebase-upload" accept=".json" class="upload-btn" title="Upload Credentials" />
#         </div>
#         <div class="form-group">
#             <label for="tab-selector">Select Tab:</label>
#             <select id="tab-selector">
#                 <option value="Overall Progress">Overall Progress</option>
#                 <option value="Individual Progress">Individual Progress</option>
#                 <option value="Top Performer">Top Performer</option>
#                 <option value="Monthly Summary">Monthly Summary</option>
#             </select>
#         </div>
#         <div class="form-group">
#             <label for="date-picker">Select Date:</label>
#             <input type="date" id="date-picker">
#         </div>
#         <button id="update-button" class="search-btn">Show results</button>
#     </div>
#     <div id="output" class="charts"></div>
# </div>
#
# <div class="container" id="search-gui" style="display: none;">
#     <div class="header">
#         <h1>Search Database</h1>
#         <div class="form-group">
#             <label for="student-name">Student Name:</label>
#             <input type="text" id="student-name">
#         </div>
#         <div class="form-group">
#             <label for="search-date-picker">Select Date:</label>
#             <input type="date" id="search-date-picker">
#         </div>
#         <div class="form-group">
#             <label for="tab">Tab:</label>
#             <input type="text" id="tab">
#         </div>
#         <div class="form-group">
#             <label for="document">Document:</label>
#             <input type="text" id="document">
#         </div>
#         <div class="form-group">
#             <label for="description">Description:</label>
#             <input type="text" id="description">
#         </div>
#         <div class="form-group">
#             <label for="keyword">Keyword:</label>
#             <input type="text" id="keyword">
#         </div>
#         <div class="centered">
#             <button id="search-submit-button" class="search-btn">Search</button>
#         </div>
#         <div class="upload-container">
#             <small>Upload credentials.json</small>
#             <input type="file" id="firebase-upload-search" accept=".json" class="upload-btn" title="Upload Credentials" />
#         </div>
#         <div>
#             <button id="back-button" class="back-btn">Back to Main</button>
#         </div>
#     </div>
#     <div id="search-output" class="search-output"></div>
# </div>
# <div class="container" id="report-gui" style="display: none;">
#     <div class="header">
#         <h1>Student Performance Report</h1>
#         <div class="form-group">
#             <label for="student_name">Student Name:</label>
#             <input type="text" id="student_name">
#         </div>
#         <div class="form-group">
#             <label for="from_date">From Date:</label>
#             <input type="date" id="from_date">
#         </div>
#         <div class="form-group">
#             <label for="to_date">To Date:</label>
#             <input type="date" id="to_date">
#         </div>
#         <div class="centered">
#             <button id="make-report-button" class="make-report-btn">Generate Report</button>
#         </div>
#
#         <div>
#             <button id="back-button2" class="back-btn">Back to Main</button>
#         </div>
#     </div>
#     <div id="search-output" class="search-output"></div>
# </div>
# <div id="modal" class="modal">
#     <div class="modal-content">
#         <p id="modal-message"></p>
#         <button id="close-modal" class="centered">Close</button>
#     </div>
# </div>
# <script>
# document.getElementById('update-button').addEventListener('click', () => {
#     const tab = document.getElementById('tab-selector').value;
#     const date = document.getElementById('date-picker').value;
#     google.colab.kernel.invokeFunction('updateData', [tab, date], {});
# });
#
# document.getElementById('search-button').addEventListener('click', () => {
#     document.getElementById('main-gui').style.display = 'none';
#     document.getElementById('search-gui').style.display = 'block';
# });
#
# document.getElementById('report-button').addEventListener('click', () => {
#     document.getElementById('main-gui').style.display = 'none';
#     document.getElementById('report-gui').style.display = 'block';
# });
#
# document.getElementById('back-button').addEventListener('click', () => {
#     document.getElementById('main-gui').style.display = 'block';
#     document.getElementById('search-gui').style.display = 'none';
# });
#
# document.getElementById('back-button2').addEventListener('click', () => {
#     document.getElementById('main-gui').style.display = 'block';
#     document.getElementById('report-gui').style.display = 'none';
# });
#
# document.getElementById('search-submit-button').addEventListener('click', () => {
#     const studentName = document.getElementById('student-name').value;
#     const date = document.getElementById('search-date-picker').value;
#     const tab = document.getElementById('tab').value;
#     const documentText = document.getElementById('document').value;
#     const description = document.getElementById('description').value;
#     const keyword = document.getElementById('keyword').value;
#     google.colab.kernel.invokeFunction('searchDatabase', [studentName, date, tab, documentText, description, keyword], {});
# });
#
# document.getElementById('make-report-button').addEventListener('click', () => {
#     const studentName = document.getElementById('student_name').value;
#     const fromDate = document.getElementById('from_date').value;
#     const toDate = document.getElementById('to_date').value;
#
#     google.colab.kernel.invokeFunction('generateReport', [studentName, fromDate, toDate], {}).then(result => {
#         let b64_pdf = result.data['text/plain'];
#         b64_pdf = b64_pdf.replace(/^'|'$/g, ''); // Remove leading and trailing single quotes if present
#         if (b64_pdf) {
#             const link = document.createElement('a');
#             link.href = `data:application/pdf;base64,${b64_pdf}`;
#             link.download = `${studentName}-${fromDate}-${toDate}.pdf`; // Change the filename here
#             document.body.appendChild(link);
#             link.click();
#             document.body.removeChild(link);
#         } else {
#             alert("Failed to generate the report. Please try again.");
#         }
#     });
# });
#
#
#
#
#
#
# function handleFileUpload(event) {
#     const file = event.target.files[0];
#     const reader = new FileReader();
#     reader.onload = function(e) {
#         const contents = e.target.result;
#         try {
#             const jsonContents = JSON.parse(contents);
#             google.colab.kernel.invokeFunction('initFirebase', [jsonContents], {});
#             showModal('Credentials file uploaded successfully.');
#         } catch (error) {
#             showModal('Invalid JSON file.');
#         }
#     };
#     reader.readAsText(file);
# }
#
# document.getElementById('firebase-upload').addEventListener('change', handleFileUpload);
#
# document.getElementById('firebase-upload-search').addEventListener('change', handleFileUpload);
#
# document.getElementById('close-modal').addEventListener('click', () => {
#     document.getElementById('modal').style.display = 'none';
# });
#
# function showModal(message) {
#     document.getElementById('modal-message').innerText = message;
#     document.getElementById('modal').style.display = 'block';
# }
# </script>

# %%
import requests
from bs4 import BeautifulSoup
import re
import firebase_admin
from firebase_admin import credentials, db
from nltk.stem import PorterStemmer
import nltk

nltk.download('punkt')

# Function to fetch and parse the page
def fetch_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    else:
        return None

# Function to index significant words
def index_words(soup):
    index = {}
    words = re.findall(r'\w+', soup.get_text())
    for word in words:
        word = word.lower()
        if word in index:
            index[word] += 1
        else:
            index[word] = 1
    return index

# Remove stop words
def remove_stop_words(index):
    stop_words = {'a', 'an', 'the', 'and', 'or', 'in', 'on', 'at', 'to'}
    for stop_word in stop_words:
        if stop_word in index:
            del index[stop_word]
    return index

# Apply stemming
def apply_stemming(index):
    stemmer = PorterStemmer()
    stemmed_index = {}
    for word, count in index.items():
        stemmed_word = stemmer.stem(word)
        if stemmed_word in stemmed_index:
            stemmed_index[stemmed_word] += count
        else:
            stemmed_index[stemmed_word] = count
    return stemmed_index

# Function to create an index for the glossary
def create_glossary_index(url):
    soup = fetch_page(url)
    if soup is None:
        return None
    index = index_words(soup)
    index = remove_stop_words(index)
    index = apply_stemming(index)
    return index

# Check if Firebase app is already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate("/content/phoenixes-f3288-firebase-adminsdk-nydgl-2a1de6a8ed.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://phoenixes-34c33-default-rtdb.europe-west1.firebasedatabase.app/'
    })

# URL of the glossary page
url = 'https://en.wikipedia.org/wiki/Glossary_of_architecture'
index = create_glossary_index(url)

# Verify the indexed data
if index:
    print("Indexed data:")
    for word, freq in index.items():
        print(f"Term: {word}, Frequency: {freq}")
else:
    print("Indexing failed. No data found.")

# Convert the index to the required format
index_data = [{'term': word, 'freq': freq} for word, freq in index.items()]

# Save the index data to Firebase
ref = db.reference('glossary_index')
ref.set(index_data)

print("Indexed data has been saved to Firebase.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Indexed data:
# Term: glossari, Frequency: 19
# Term: of, Frequency: 420
# Term: architectur, Frequency: 95
# Term: wikipedia, Frequency: 7
# Term: jump, Frequency: 1
# Term: content, Frequency: 3
# Term: main, Frequency: 17
# Term: menu, Frequency: 2
# Term: move, Frequency: 5
# Term: sidebar, Frequency: 3
# Term: hide, Frequency: 5
# Term: navig, Frequency: 1
# Term: pagecontentscurr, Frequency: 1
# Term: eventsrandom, Frequency: 1
# Term: articleabout, Frequency: 1
# Term: wikipediacontact, Frequency: 1
# Term: usdon, Frequency: 1
# Term: contribut, Frequency: 1
# Term: helplearn, Frequency: 1
# Term: editcommun, Frequency: 1
# Term: portalrec, Frequency: 1
# Term: changesupload, Frequency: 2
# Term: file, Frequency: 1
# Term: search, Frequency: 3
# Term: appear, Frequency: 3
# Term: creat, Frequency: 7
# Term: account, Frequency: 2
# Term: log, Frequency: 4
# Term: person, Frequency: 1
# Term: tool, Frequency: 3
# Term: page, Frequency: 6
# Term: for, Frequency: 33
# Term: out, Frequency: 4
# Term: editor, Frequency: 1
# Term: learn, Frequency: 1
# Term: more, Frequency: 13
# Term: contributionstalk, Frequency: 1
# Term: 9, Frequency: 6
# Term: languag, Frequency: 2
# Term: azərbaycancabrezhonegcymraegdeutschespañolesperantofrançaisidoromână, Frequency: 1
# Term: edit, Frequency: 40
# Term: link, Frequency: 3
# Term: articletalk, Frequency: 1
# Term: english, Frequency: 9
# Term: readeditview, Frequency: 2
# Term: histori, Frequency: 10
# Term: action, Frequency: 1
# Term: gener, Frequency: 12
# Term: what, Frequency: 2
# Term: hererel, Frequency: 1
# Term: filespeci, Frequency: 1
# Term: pagesperman, Frequency: 1
# Term: linkpag, Frequency: 1
# Term: informationcit, Frequency: 1
# Term: thi, Frequency: 16
# Term: pageget, Frequency: 1
# Term: shorten, Frequency: 1
# Term: urldownload, Frequency: 1
# Term: qr, Frequency: 1
# Term: codewikidata, Frequency: 1
# Term: item, Frequency: 1
# Term: print, Frequency: 2
# Term: export, Frequency: 1
# Term: download, Frequency: 1
# Term: as, Frequency: 57
# Term: pdfprintabl, Frequency: 1
# Term: version, Frequency: 1
# Term: from, Frequency: 65
# Term: free, Frequency: 3
# Term: encyclopedia, Frequency: 1
# Term: list, Frequency: 7
# Term: definit, Frequency: 1
# Term: term, Frequency: 35
# Term: concept, Frequency: 1
# Term: use, Frequency: 44
# Term: is, Frequency: 84
# Term: top, Frequency: 24
# Term: b, Frequency: 4
# Term: c, Frequency: 4
# Term: d, Frequency: 3
# Term: e, Frequency: 5
# Term: f, Frequency: 3
# Term: g, Frequency: 2
# Term: h, Frequency: 3
# Term: i, Frequency: 7
# Term: j, Frequency: 2
# Term: k, Frequency: 3
# Term: l, Frequency: 4
# Term: m, Frequency: 6
# Term: n, Frequency: 3
# Term: o, Frequency: 2
# Term: p, Frequency: 46
# Term: q, Frequency: 4
# Term: r, Frequency: 2
# Term: s, Frequency: 30
# Term: t, Frequency: 2
# Term: u, Frequency: 2
# Term: v, Frequency: 7
# Term: w, Frequency: 3
# Term: z, Frequency: 5
# Term: see, Frequency: 6
# Term: also, Frequency: 35
# Term: note, Frequency: 3
# Term: refer, Frequency: 8
# Term: abacu, Frequency: 5
# Term: flat, Frequency: 11
# Term: slab, Frequency: 3
# Term: form, Frequency: 22
# Term: uppermost, Frequency: 3
# Term: member, Frequency: 16
# Term: divis, Frequency: 4
# Term: capit, Frequency: 13
# Term: column, Frequency: 57
# Term: accolad, Frequency: 1
# Term: sculptur, Frequency: 3
# Term: embellish, Frequency: 2
# Term: arch, Frequency: 25
# Term: aisl, Frequency: 4
# Term: subsidiari, Frequency: 1
# Term: space, Frequency: 21
# Term: alongsid, Frequency: 1
# Term: bodi, Frequency: 4
# Term: build, Frequency: 60
# Term: separ, Frequency: 7
# Term: it, Frequency: 47
# Term: by, Frequency: 55
# Term: pier, Frequency: 7
# Term: post, Frequency: 8
# Term: ant, Frequency: 1
# Term: choir, Frequency: 3
# Term: enclos, Frequency: 17
# Term: church, Frequency: 19
# Term: between, Frequency: 33
# Term: outer, Frequency: 3
# Term: gate, Frequency: 1
# Term: rail, Frequency: 12
# Term: rood, Frequency: 1
# Term: screen, Frequency: 10
# Term: door, Frequency: 12
# Term: apron, Frequency: 1
# Term: 1, Frequency: 11
# Term: rais, Frequency: 8
# Term: panel, Frequency: 10
# Term: below, Frequency: 8
# Term: window, Frequency: 34
# Term: wall, Frequency: 48
# Term: monument, Frequency: 3
# Term: tablet, Frequency: 1
# Term: 2, Frequency: 7
# Term: open, Frequency: 22
# Term: portion, Frequency: 6
# Term: marin, Frequency: 1
# Term: termin, Frequency: 8
# Term: immedi, Frequency: 2
# Term: adjac, Frequency: 1
# Term: vessel, Frequency: 2
# Term: berth, Frequency: 1
# Term: direct, Frequency: 5
# Term: transfer, Frequency: 3
# Term: cargo, Frequency: 1
# Term: 3, Frequency: 5
# Term: concret, Frequency: 3
# Term: outsid, Frequency: 4
# Term: vehicular, Frequency: 1
# Term: passageway, Frequency: 3
# Term: limit, Frequency: 2
# Term: wear, Frequency: 1
# Term: asphalt, Frequency: 1
# Term: pave, Frequency: 3
# Term: due, Frequency: 1
# Term: repetit, Frequency: 1
# Term: turn, Frequency: 1
# Term: movement, Frequency: 1
# Term: heavi, Frequency: 5
# Term: load, Frequency: 6
# Term: aps, Frequency: 3
# Term: vault, Frequency: 23
# Term: semicircular, Frequency: 3
# Term: polygon, Frequency: 1
# Term: end, Frequency: 19
# Term: chancel, Frequency: 4
# Term: chapel, Frequency: 6
# Term: that, Frequency: 65
# Term: usual, Frequency: 24
# Term: christian, Frequency: 2
# Term: beyond, Frequency: 3
# Term: cross, Frequency: 7
# Term: opposit, Frequency: 1
# Term: nave, Frequency: 5
# Term: some, Frequency: 13
# Term: seat, Frequency: 5
# Term: araeostyl, Frequency: 2
# Term: style, Frequency: 10
# Term: intercolumni, Frequency: 12
# Term: which, Frequency: 76
# Term: distanc, Frequency: 4
# Term: least, Frequency: 1
# Term: four, Frequency: 6
# Term: diamet, Frequency: 7
# Term: larg, Frequency: 11
# Term: interv, Frequency: 4
# Term: necessit, Frequency: 1
# Term: wooden, Frequency: 4
# Term: architrav, Frequency: 7
# Term: araeosystyl, Frequency: 2
# Term: appli, Frequency: 6
# Term: colonnad, Frequency: 4
# Term: altern, Frequency: 5
# Term: wide, Frequency: 2
# Term: narrow, Frequency: 3
# Term: arcad, Frequency: 4
# Term: passag, Frequency: 8
# Term: walkway, Frequency: 2
# Term: cover, Frequency: 10
# Term: over, Frequency: 11
# Term: success, Frequency: 3
# Term: support, Frequency: 27
# Term: blind, Frequency: 1
# Term: same, Frequency: 7
# Term: surfac, Frequency: 10
# Term: curv, Frequency: 15
# Term: structur, Frequency: 47
# Term: capabl, Frequency: 1
# Term: span, Frequency: 3
# Term: while, Frequency: 2
# Term: signific, Frequency: 1
# Term: weight, Frequency: 6
# Term: formal, Frequency: 1
# Term: lintel, Frequency: 4
# Term: lowest, Frequency: 5
# Term: classic, Frequency: 21
# Term: entablatur, Frequency: 13
# Term: mould, Frequency: 21
# Term: frame, Frequency: 9
# Term: often, Frequency: 30
# Term: borrow, Frequency: 1
# Term: profil, Frequency: 2
# Term: area, Frequency: 10
# Term: basement, Frequency: 3
# Term: georgian, Frequency: 2
# Term: small, Frequency: 21
# Term: yard, Frequency: 1
# Term: give, Frequency: 3
# Term: entri, Frequency: 1
# Term: via, Frequency: 2
# Term: step, Frequency: 6
# Term: floor, Frequency: 9
# Term: front, Frequency: 5
# Term: terrac, Frequency: 4
# Term: hous, Frequency: 16
# Term: arri, Frequency: 4
# Term: sharp, Frequency: 3
# Term: edg, Frequency: 15
# Term: when, Frequency: 5
# Term: two, Frequency: 29
# Term: converg, Frequency: 1
# Term: includ, Frequency: 4
# Term: flute, Frequency: 6
# Term: pilast, Frequency: 11
# Term: if, Frequency: 5
# Term: type, Frequency: 12
# Term: with, Frequency: 62
# Term: section, Frequency: 5
# Term: resembl, Frequency: 6
# Term: isoscel, Frequency: 1
# Term: triangl, Frequency: 1
# Term: arrowslit, Frequency: 1
# Term: thin, Frequency: 1
# Term: vertic, Frequency: 22
# Term: apertur, Frequency: 1
# Term: fortif, Frequency: 5
# Term: through, Frequency: 10
# Term: archer, Frequency: 1
# Term: can, Frequency: 6
# Term: launch, Frequency: 1
# Term: arrow, Frequency: 3
# Term: articul, Frequency: 1
# Term: manner, Frequency: 2
# Term: method, Frequency: 3
# Term: joint, Frequency: 6
# Term: part, Frequency: 18
# Term: such, Frequency: 17
# Term: each, Frequency: 7
# Term: clear, Frequency: 1
# Term: distinct, Frequency: 1
# Term: relat, Frequency: 2
# Term: other, Frequency: 15
# Term: even, Frequency: 2
# Term: though, Frequency: 5
# Term: join, Frequency: 2
# Term: ashlar, Frequency: 2
# Term: masonri, Frequency: 4
# Term: block, Frequency: 12
# Term: cut, Frequency: 6
# Term: face, Frequency: 10
# Term: squar, Frequency: 9
# Term: astrag, Frequency: 2
# Term: compos, Frequency: 1
# Term: half, Frequency: 7
# Term: round, Frequency: 11
# Term: surround, Frequency: 6
# Term: plane, Frequency: 5
# Term: fillet, Frequency: 7
# Term: atla, Frequency: 1
# Term: sculpt, Frequency: 2
# Term: man, Frequency: 1
# Term: may, Frequency: 14
# Term: take, Frequency: 3
# Term: place, Frequency: 17
# Term: atrium, Frequency: 2
# Term: plural, Frequency: 3
# Term: atria, Frequency: 1
# Term: inner, Frequency: 5
# Term: court, Frequency: 5
# Term: roman, Frequency: 10
# Term: multi, Frequency: 1
# Term: stori, Frequency: 7
# Term: toplit, Frequency: 1
# Term: rise, Frequency: 3
# Term: all, Frequency: 6
# Term: attic, Frequency: 2
# Term: within, Frequency: 10
# Term: roof, Frequency: 38
# Term: abov, Frequency: 18
# Term: ceil, Frequency: 5
# Term: façad, Frequency: 1
# Term: balconet, Frequency: 1
# Term: fals, Frequency: 1
# Term: balconi, Frequency: 2
# Term: ball, Frequency: 2
# Term: flower, Frequency: 4
# Term: ornament, Frequency: 16
# Term: insert, Frequency: 3
# Term: cup, Frequency: 1
# Term: came, Frequency: 2
# Term: into, Frequency: 7
# Term: latter, Frequency: 2
# Term: 13th, Frequency: 1
# Term: wa, Frequency: 14
# Term: great, Frequency: 6
# Term: vogu, Frequency: 1
# Term: earli, Frequency: 4
# Term: 14th, Frequency: 1
# Term: centuri, Frequency: 9
# Term: fanci, Frequency: 1
# Term: balust, Frequency: 4
# Term: shaft, Frequency: 9
# Term: circular, Frequency: 8
# Term: stone, Frequency: 25
# Term: wood, Frequency: 12
# Term: sometim, Frequency: 20
# Term: metal, Frequency: 9
# Term: cope, Frequency: 5
# Term: parapet, Frequency: 6
# Term: handrail, Frequency: 3
# Term: staircas, Frequency: 3
# Term: seri, Frequency: 8
# Term: call, Frequency: 14
# Term: balustrad, Frequency: 2
# Term: bar, Frequency: 5
# Term: stay, Frequency: 1
# Term: girder, Frequency: 10
# Term: inadequ, Frequency: 1
# Term: capac, Frequency: 3
# Term: augment, Frequency: 3
# Term: one, Frequency: 29
# Term: steel, Frequency: 6
# Term: anchor, Frequency: 2
# Term: bear, Frequency: 3
# Term: centroid, Frequency: 1
# Term: assum, Frequency: 1
# Term: tension, Frequency: 1
# Term: forc, Frequency: 3
# Term: run, Frequency: 7
# Term: down, Frequency: 3
# Term: stand, Frequency: 3
# Term: off, Frequency: 4
# Term: strut, Frequency: 2
# Term: bottom, Frequency: 6
# Term: are, Frequency: 47
# Term: size, Frequency: 3
# Term: accept, Frequency: 1
# Term: compress, Frequency: 2
# Term: impos, Frequency: 3
# Term: without, Frequency: 2
# Term: bend, Frequency: 2
# Term: crippl, Frequency: 2
# Term: horizont, Frequency: 19
# Term: failur, Frequency: 2
# Term: bargeboard, Frequency: 1
# Term: board, Frequency: 6
# Term: fasten, Frequency: 1
# Term: project, Frequency: 26
# Term: gabl, Frequency: 19
# Term: barrel, Frequency: 3
# Term: element, Frequency: 20
# Term: extrus, Frequency: 1
# Term: singl, Frequency: 2
# Term: pair, Frequency: 1
# Term: case, Frequency: 3
# Term: point, Frequency: 5
# Term: along, Frequency: 10
# Term: given, Frequency: 5
# Term: bartizan, Frequency: 1
# Term: overhang, Frequency: 3
# Term: mount, Frequency: 4
# Term: turret, Frequency: 3
# Term: corner, Frequency: 4
# Term: mediev, Frequency: 12
# Term: subordin, Frequency: 2
# Term: storey, Frequency: 3
# Term: either, Frequency: 9
# Term: entir, Frequency: 1
# Term: partial, Frequency: 2
# Term: ground, Frequency: 6
# Term: level, Frequency: 5
# Term: elev, Frequency: 1
# Term: piano, Frequency: 2
# Term: nobil, Frequency: 2
# Term: basilica, Frequency: 4
# Term: origin, Frequency: 8
# Term: hall, Frequency: 8
# Term: erect, Frequency: 1
# Term: transact, Frequency: 1
# Term: busi, Frequency: 1
# Term: dispos, Frequency: 1
# Term: legal, Frequency: 1
# Term: matter, Frequency: 1
# Term: later, Frequency: 6
# Term: describ, Frequency: 4
# Term: clerestori, Frequency: 2
# Term: cathedr, Frequency: 1
# Term: plan, Frequency: 6
# Term: were, Frequency: 6
# Term: develop, Frequency: 4
# Term: batement, Frequency: 2
# Term: light, Frequency: 10
# Term: upper, Frequency: 14
# Term: perpendicular, Frequency: 4
# Term: abat, Frequency: 1
# Term: onli, Frequency: 5
# Term: width, Frequency: 3
# Term: those, Frequency: 4
# Term: batter, Frequency: 1
# Term: upwardli, Frequency: 1
# Term: reced, Frequency: 3
# Term: slope, Frequency: 17
# Term: battlement, Frequency: 1
# Term: defens, Frequency: 1
# Term: low, Frequency: 4
# Term: chest, Frequency: 1
# Term: height, Frequency: 3
# Term: head, Frequency: 6
# Term: rectangular, Frequency: 8
# Term: gap, Frequency: 1
# Term: indent, Frequency: 1
# Term: occur, Frequency: 3
# Term: allow, Frequency: 5
# Term: discharg, Frequency: 1
# Term: missil, Frequency: 1
# Term: bay, Frequency: 3
# Term: intern, Frequency: 5
# Term: compart, Frequency: 1
# Term: divid, Frequency: 4
# Term: subtl, Frequency: 1
# Term: mean, Frequency: 4
# Term: boundari, Frequency: 2
# Term: impli, Frequency: 1
# Term: mark, Frequency: 3
# Term: side, Frequency: 23
# Term: etc, Frequency: 4
# Term: beam, Frequency: 9
# Term: extern, Frequency: 3
# Term: fenestr, Frequency: 1
# Term: cant, Frequency: 2
# Term: straight, Frequency: 7
# Term: angl, Frequency: 7
# Term: bow, Frequency: 1
# Term: oriel, Frequency: 1
# Term: rest, Frequency: 3
# Term: corbel, Frequency: 5
# Term: bracket, Frequency: 4
# Term: start, Frequency: 2
# Term: dai, Frequency: 2
# Term: belfri, Frequency: 1
# Term: chamber, Frequency: 9
# Term: stage, Frequency: 2
# Term: tower, Frequency: 4
# Term: where, Frequency: 8
# Term: bell, Frequency: 2
# Term: hung, Frequency: 3
# Term: brick, Frequency: 4
# Term: laid, Frequency: 2
# Term: so, Frequency: 7
# Term: they, Frequency: 14
# Term: interlock, Frequency: 2
# Term: bench, Frequency: 3
# Term: tabl, Frequency: 2
# Term: veri, Frequency: 2
# Term: porch, Frequency: 6
# Term: bond, Frequency: 2
# Term: brickwork, Frequency: 5
# Term: overlap, Frequency: 2
# Term: stretcher, Frequency: 1
# Term: header, Frequency: 2
# Term: flemish, Frequency: 1
# Term: garden, Frequency: 7
# Term: herringbon, Frequency: 1
# Term: basket, Frequency: 1
# Term: american, Frequency: 5
# Term: chines, Frequency: 2
# Term: boss, Frequency: 1
# Term: roughli, Frequency: 1
# Term: set, Frequency: 5
# Term: carv, Frequency: 8
# Term: keyston, Frequency: 3
# Term: rib, Frequency: 9
# Term: intersect, Frequency: 9
# Term: ogiv, Frequency: 1
# Term: bossag, Frequency: 3
# Term: uncut, Frequency: 1
# Term: outward, Frequency: 3
# Term: be, Frequency: 24
# Term: decor, Frequency: 23
# Term: arm, Frequency: 1
# Term: rustic, Frequency: 2
# Term: work, Frequency: 5
# Term: consist, Frequency: 9
# Term: seem, Frequency: 1
# Term: advanc, Frequency: 1
# Term: reason, Frequency: 1
# Term: indentur, Frequency: 2
# Term: channel, Frequency: 1
# Term: left, Frequency: 4
# Term: chiefli, Frequency: 1
# Term: quoin, Frequency: 3
# Term: caviti, Frequency: 1
# Term: chamfer, Frequency: 5
# Term: bevel, Frequency: 1
# Term: diamond, Frequency: 1
# Term: shape, Frequency: 19
# Term: cavetto, Frequency: 3
# Term: listel, Frequency: 1
# Term: boutant, Frequency: 4
# Term: arc, Frequency: 1
# Term: fli, Frequency: 4
# Term: buttress, Frequency: 7
# Term: serv, Frequency: 8
# Term: sustain, Frequency: 2
# Term: self, Frequency: 1
# Term: strong, Frequency: 1
# Term: massiv, Frequency: 1
# Term: pillar, Frequency: 6
# Term: chain, Frequency: 1
# Term: jamb, Frequency: 1
# Term: made, Frequency: 7
# Term: word, Frequency: 5
# Term: french, Frequency: 6
# Term: come, Frequency: 3
# Term: verb, Frequency: 1
# Term: bouter, Frequency: 1
# Term: butt, Frequency: 1
# Term: abut, Frequency: 3
# Term: 4, Frequency: 4
# Term: bressumm, Frequency: 1
# Term: liter, Frequency: 2
# Term: breast, Frequency: 2
# Term: especi, Frequency: 6
# Term: jetti, Frequency: 2
# Term: brise, Frequency: 1
# Term: soleil, Frequency: 1
# Term: fin, Frequency: 1
# Term: canopi, Frequency: 1
# Term: shade, Frequency: 1
# Term: sunlight, Frequency: 1
# Term: broken, Frequency: 1
# Term: pediment, Frequency: 7
# Term: center, Frequency: 4
# Term: stop, Frequency: 2
# Term: short, Frequency: 2
# Term: apex, Frequency: 2
# Term: variant, Frequency: 1
# Term: ess, Frequency: 1
# Term: swan, Frequency: 1
# Term: neck, Frequency: 1
# Term: bullsey, Frequency: 1
# Term: oval, Frequency: 2
# Term: glass, Frequency: 4
# Term: bulwark, Frequency: 1
# Term: barricad, Frequency: 1
# Term: soil, Frequency: 1
# Term: 15th, Frequency: 1
# Term: 16th, Frequency: 2
# Term: design, Frequency: 10
# Term: artilleri, Frequency: 1
# Term: ship, Frequency: 2
# Term: woodwork, Frequency: 1
# Term: deck, Frequency: 1
# Term: figur, Frequency: 5
# Term: anyth, Frequency: 1
# Term: defenc, Frequency: 1
# Term: dutch, Frequency: 3
# Term: loanword, Frequency: 1
# Term: bolwerk, Frequency: 1
# Term: stabil, Frequency: 1
# Term: resist, Frequency: 3
# Term: thrust, Frequency: 3
# Term: transmit, Frequency: 3
# Term: cancellu, Frequency: 1
# Term: cancelli, Frequency: 3
# Term: barrier, Frequency: 1
# Term: correspond, Frequency: 1
# Term: modern, Frequency: 7
# Term: occupi, Frequency: 1
# Term: minist, Frequency: 1
# Term: henc, Frequency: 1
# Term: employ, Frequency: 2
# Term: partit, Frequency: 3
# Term: law, Frequency: 1
# Term: 5, Frequency: 6
# Term: obliqu, Frequency: 2
# Term: line, Frequency: 3
# Term: cantilev, Frequency: 1
# Term: unsupport, Frequency: 1
# Term: act, Frequency: 1
# Term: lever, Frequency: 1
# Term: like, Frequency: 7
# Term: flagpol, Frequency: 1
# Term: stick, Frequency: 1
# Term: topmost, Frequency: 1
# Term: caryatid, Frequency: 2
# Term: erechtheion, Frequency: 1
# Term: athen, Frequency: 2
# Term: 421, Frequency: 1
# Term: 407, Frequency: 1
# Term: bc, Frequency: 1
# Term: femal, Frequency: 1
# Term: her, Frequency: 1
# Term: casement, Frequency: 2
# Term: hing, Frequency: 1
# Term: swing, Frequency: 1
# Term: inward, Frequency: 1
# Term: cauliculu, Frequency: 2
# Term: caulicol, Frequency: 1
# Term: stalk, Frequency: 1
# Term: eight, Frequency: 1
# Term: number, Frequency: 4
# Term: leav, Frequency: 2
# Term: helic, Frequency: 1
# Term: spiral, Frequency: 4
# Term: scroll, Frequency: 7
# Term: corinthian, Frequency: 7
# Term: 6, Frequency: 8
# Term: neg, Frequency: 1
# Term: make, Frequency: 4
# Term: quarter, Frequency: 5
# Term: circl, Frequency: 6
# Term: 7, Frequency: 4
# Term: cella, Frequency: 5
# Term: templ, Frequency: 24
# Term: chalcidicum, Frequency: 2
# Term: vestibul, Frequency: 2
# Term: portico, Frequency: 13
# Term: public, Frequency: 5
# Term: forum, Frequency: 1
# Term: eumachia, Frequency: 1
# Term: pompeii, Frequency: 1
# Term: constantin, Frequency: 1
# Term: rome, Frequency: 4
# Term: lacunar, Frequency: 4
# Term: 8, Frequency: 1
# Term: transit, Frequency: 1
# Term: 45, Frequency: 2
# Term: degre, Frequency: 1
# Term: pare, Frequency: 1
# Term: diagon, Frequency: 4
# Term: base, Frequency: 13
# Term: octagon, Frequency: 3
# Term: presbyteri, Frequency: 1
# Term: around, Frequency: 6
# Term: altar, Frequency: 4
# Term: east, Frequency: 2
# Term: tradit, Frequency: 8
# Term: sanctuari, Frequency: 3
# Term: chandrashala, Frequency: 1
# Term: horsesho, Frequency: 1
# Term: mani, Frequency: 2
# Term: indian, Frequency: 3
# Term: cave, Frequency: 1
# Term: shrine, Frequency: 4
# Term: chigi, Frequency: 4
# Term: japanes, Frequency: 9
# Term: finial, Frequency: 6
# Term: almost, Frequency: 2
# Term: exclus, Frequency: 1
# Term: shinto, Frequency: 3
# Term: near, Frequency: 3
# Term: ridgelin, Frequency: 2
# Term: extens, Frequency: 1
# Term: attach, Frequency: 7
# Term: most, Frequency: 6
# Term: indic, Frequency: 2
# Term: sex, Frequency: 2
# Term: kami, Frequency: 2
# Term: chimera, Frequency: 1
# Term: fantast, Frequency: 1
# Term: mythic, Frequency: 1
# Term: grotesqu, Frequency: 2
# Term: purpos, Frequency: 7
# Term: chimney, Frequency: 1
# Term: provid, Frequency: 4
# Term: ventil, Frequency: 4
# Term: chresmographion, Frequency: 2
# Term: pronao, Frequency: 1
# Term: greek, Frequency: 17
# Term: oracl, Frequency: 1
# Term: deliv, Frequency: 1
# Term: 10, Frequency: 4
# Term: cinctur, Frequency: 2
# Term: ring, Frequency: 1
# Term: 11, Frequency: 9
# Term: cinquecento, Frequency: 1
# Term: becam, Frequency: 2
# Term: preval, Frequency: 1
# Term: itali, Frequency: 1
# Term: follow, Frequency: 2
# Term: 1500, Frequency: 1
# Term: now, Frequency: 3
# Term: result, Frequency: 1
# Term: reviv, Frequency: 3
# Term: known, Frequency: 12
# Term: renaiss, Frequency: 3
# Term: but, Frequency: 15
# Term: chang, Frequency: 1
# Term: had, Frequency: 4
# Term: commenc, Frequency: 1
# Term: alreadi, Frequency: 1
# Term: earlier, Frequency: 3
# Term: ghiberti, Frequency: 1
# Term: donatello, Frequency: 1
# Term: brunelleschi, Frequency: 1
# Term: alberti, Frequency: 1
# Term: 12, Frequency: 5
# Term: cippu, Frequency: 2
# Term: cippi, Frequency: 2
# Term: pedest, Frequency: 5
# Term: up, Frequency: 6
# Term: militari, Frequency: 1
# Term: mileston, Frequency: 1
# Term: inscript, Frequency: 1
# Term: british, Frequency: 1
# Term: museum, Frequency: 3
# Term: show, Frequency: 1
# Term: occasion, Frequency: 2
# Term: funer, Frequency: 1
# Term: memori, Frequency: 1
# Term: 13, Frequency: 5
# Term: circul, Frequency: 1
# Term: flow, Frequency: 2
# Term: peopl, Frequency: 1
# Term: throughout, Frequency: 1
# Term: cleithral, Frequency: 3
# Term: contradistinct, Frequency: 1
# Term: hypaethr, Frequency: 1
# Term: uncov, Frequency: 1
# Term: complet, Frequency: 1
# Term: 14, Frequency: 2
# Term: contain, Frequency: 3
# Term: clock, Frequency: 1
# Term: facad, Frequency: 3
# Term: characterist, Frequency: 2
# Term: coffer, Frequency: 2
# Term: sunken, Frequency: 2
# Term: rectangl, Frequency: 1
# Term: devic, Frequency: 2
# Term: caisson, Frequency: 1
# Term: 15, Frequency: 2
# Term: colarin, Frequency: 1
# Term: hypotrachelium, Frequency: 3
# Term: colarino, Frequency: 1
# Term: collarino, Frequency: 1
# Term: littl, Frequency: 1
# Term: friez, Frequency: 6
# Term: tuscan, Frequency: 1
# Term: doric, Frequency: 12
# Term: annulet, Frequency: 1
# Term: vitruviu, Frequency: 5
# Term: compass, Frequency: 2
# Term: carpentri, Frequency: 1
# Term: shipbuild, Frequency: 1
# Term: compluvium, Frequency: 2
# Term: latin, Frequency: 2
# Term: domu, Frequency: 1
# Term: room, Frequency: 12
# Term: 16, Frequency: 2
# Term: cap, Frequency: 1
# Term: piec, Frequency: 7
# Term: jut, Frequency: 1
# Term: carri, Frequency: 9
# Term: superincumb, Frequency: 1
# Term: corbi, Frequency: 4
# Term: zaltbommel, Frequency: 1
# Term: corbiestep, Frequency: 2
# Term: 17, Frequency: 2
# Term: crow, Frequency: 2
# Term: featur, Frequency: 7
# Term: 18, Frequency: 2
# Term: order, Frequency: 23
# Term: three, Frequency: 11
# Term: organis, Frequency: 3
# Term: system, Frequency: 3
# Term: ancient, Frequency: 11
# Term: characteris, Frequency: 3
# Term: stood, Frequency: 3
# Term: pavement, Frequency: 3
# Term: their, Frequency: 7
# Term: parallel, Frequency: 5
# Term: concav, Frequency: 6
# Term: groov, Frequency: 4
# Term: acanthu, Frequency: 1
# Term: flare, Frequency: 3
# Term: meet, Frequency: 3
# Term: cornic, Frequency: 13
# Term: shelf, Frequency: 1
# Term: cours, Frequency: 5
# Term: layer, Frequency: 1
# Term: unit, Frequency: 1
# Term: crest, Frequency: 1
# Term: ridg, Frequency: 7
# Term: springer, Frequency: 5
# Term: spring, Frequency: 2
# Term: skewback, Frequency: 1
# Term: 19, Frequency: 2
# Term: wing, Frequency: 7
# Term: axi, Frequency: 3
# Term: right, Frequency: 1
# Term: crypt, Frequency: 1
# Term: beneath, Frequency: 4
# Term: typic, Frequency: 3
# Term: coffin, Frequency: 1
# Term: sarcophagi, Frequency: 1
# Term: religi, Frequency: 1
# Term: relic, Frequency: 1
# Term: cryptoporticu, Frequency: 1
# Term: conceal, Frequency: 1
# Term: underground, Frequency: 1
# Term: air, Frequency: 2
# Term: best, Frequency: 3
# Term: exampl, Frequency: 2
# Term: crypto, Frequency: 2
# Term: porticu, Frequency: 2
# Term: under, Frequency: 8
# Term: palac, Frequency: 1
# Term: caesar, Frequency: 1
# Term: hadrian, Frequency: 1
# Term: villa, Frequency: 1
# Term: princip, Frequency: 2
# Term: privat, Frequency: 1
# Term: intercommun, Frequency: 1
# Term: sever, Frequency: 3
# Term: 20, Frequency: 2
# Term: cuneu, Frequency: 1
# Term: wedg, Frequency: 2
# Term: theatr, Frequency: 2
# Term: scala, Frequency: 1
# Term: stairway, Frequency: 1
# Term: 21, Frequency: 1
# Term: cupola, Frequency: 2
# Term: dome, Frequency: 10
# Term: cyma, Frequency: 5
# Term: whose, Frequency: 4
# Term: major, Frequency: 1
# Term: recta, Frequency: 1
# Term: reversa, Frequency: 1
# Term: oge, Frequency: 1
# Term: lower, Frequency: 10
# Term: 22, Frequency: 2
# Term: cyrto, Frequency: 2
# Term: 23, Frequency: 2
# Term: denticul, Frequency: 1
# Term: fine, Frequency: 2
# Term: tooth, Frequency: 1
# Term: notch, Frequency: 1
# Term: have, Frequency: 11
# Term: dentil, Frequency: 4
# Term: 24, Frequency: 2
# Term: string, Frequency: 1
# Term: diastyl, Frequency: 3
# Term: 25, Frequency: 2
# Term: diaulo, Frequency: 2
# Term: peristyl, Frequency: 6
# Term: palaestra, Frequency: 2
# Term: measur, Frequency: 1
# Term: stadia, Frequency: 1
# Term: 200, Frequency: 1
# Term: ft, Frequency: 1
# Term: length, Frequency: 5
# Term: south, Frequency: 2
# Term: row, Frequency: 5
# Term: stormi, Frequency: 1
# Term: weather, Frequency: 2
# Term: rain, Frequency: 1
# Term: might, Frequency: 1
# Term: not, Frequency: 7
# Term: driven, Frequency: 3
# Term: greec, Frequency: 1
# Term: foot, Frequency: 3
# Term: race, Frequency: 1
# Term: twice, Frequency: 1
# Term: 26, Frequency: 2
# Term: diazoma, Frequency: 1
# Term: theater, Frequency: 1
# Term: tier, Frequency: 1
# Term: semi, Frequency: 3
# Term: 27, Frequency: 3
# Term: dikka, Frequency: 2
# Term: islam, Frequency: 5
# Term: tribun, Frequency: 1
# Term: upon, Frequency: 4
# Term: koran, Frequency: 1
# Term: recit, Frequency: 1
# Term: prayer, Frequency: 3
# Term: inton, Frequency: 1
# Term: imam, Frequency: 2
# Term: mosqu, Frequency: 4
# Term: 28, Frequency: 2
# Term: doubl, Frequency: 4
# Term: rang, Frequency: 2
# Term: diana, Frequency: 1
# Term: ephesu, Frequency: 1
# Term: 29, Frequency: 1
# Term: distyl, Frequency: 2
# Term: anti, Frequency: 1
# Term: anta, Frequency: 1
# Term: 30, Frequency: 3
# Term: dodecastyl, Frequency: 2
# Term: ha, Frequency: 10
# Term: twelv, Frequency: 1
# Term: ad, Frequency: 2
# Term: demet, Frequency: 1
# Term: eleusi, Frequency: 1
# Term: philo, Frequency: 1
# Term: architect, Frequency: 2
# Term: arsen, Frequency: 1
# Term: peiraeu, Frequency: 1
# Term: 31, Frequency: 1
# Term: smooth, Frequency: 3
# Term: dormer, Frequency: 3
# Term: protrud, Frequency: 1
# Term: construct, Frequency: 10
# Term: addit, Frequency: 3
# Term: usabl, Frequency: 1
# Term: headroom, Frequency: 1
# Term: enabl, Frequency: 1
# Term: dosseret, Frequency: 2
# Term: impost, Frequency: 1
# Term: cubic, Frequency: 1
# Term: byzantin, Frequency: 1
# Term: superfici, Frequency: 1
# Term: greatli, Frequency: 1
# Term: excess, Frequency: 1
# Term: them, Frequency: 4
# Term: 32, Frequency: 1
# Term: depth, Frequency: 3
# Term: deep, Frequency: 2
# Term: lack, Frequency: 2
# Term: central, Frequency: 6
# Term: corridor, Frequency: 1
# Term: 33, Frequency: 1
# Term: dromo, Frequency: 3
# Term: entranc, Frequency: 6
# Term: avenu, Frequency: 2
# Term: lead, Frequency: 3
# Term: tomb, Frequency: 6
# Term: beehiv, Frequency: 1
# Term: fill, Frequency: 4
# Term: 34, Frequency: 2
# Term: 35, Frequency: 1
# Term: egypt, Frequency: 1
# Term: flank, Frequency: 2
# Term: sphinx, Frequency: 1
# Term: 36, Frequency: 1
# Term: eav, Frequency: 5
# Term: return, Frequency: 3
# Term: domest, Frequency: 2
# Term: egg, Frequency: 1
# Term: dart, Frequency: 1
# Term: ovolo, Frequency: 4
# Term: inscrib, Frequency: 1
# Term: motif, Frequency: 4
# Term: enfilad, Frequency: 2
# Term: align, Frequency: 1
# Term: doorway, Frequency: 2
# Term: linear, Frequency: 2
# Term: procession, Frequency: 1
# Term: rout, Frequency: 2
# Term: common, Frequency: 4
# Term: class, Frequency: 1
# Term: baroqu, Frequency: 2
# Term: layout, Frequency: 1
# Term: manag, Frequency: 1
# Term: engag, Frequency: 4
# Term: built, Frequency: 6
# Term: particularli, Frequency: 4
# Term: notabl, Frequency: 2
# Term: engawa, Frequency: 1
# Term: shoji, Frequency: 8
# Term: encircl, Frequency: 1
# Term: similar, Frequency: 6
# Term: itself, Frequency: 1
# Term: storm, Frequency: 1
# Term: sheet, Frequency: 3
# Term: sunroom, Frequency: 1
# Term: superstructur, Frequency: 2
# Term: band, Frequency: 3
# Term: lie, Frequency: 1
# Term: entasi, Frequency: 1
# Term: applic, Frequency: 1
# Term: convex, Frequency: 2
# Term: aesthet, Frequency: 1
# Term: certain, Frequency: 1
# Term: slightli, Frequency: 2
# Term: decreas, Frequency: 1
# Term: upward, Frequency: 1
# Term: engin, Frequency: 9
# Term: function, Frequency: 1
# Term: regard, Frequency: 1
# Term: strength, Frequency: 2
# Term: ephebeum, Frequency: 2
# Term: ephebion, Frequency: 1
# Term: furnish, Frequency: 1
# Term: should, Frequency: 1
# Term: third, Frequency: 1
# Term: larger, Frequency: 4
# Term: than, Frequency: 7
# Term: exercis, Frequency: 1
# Term: youth, Frequency: 1
# Term: sixteen, Frequency: 1
# Term: eighteen, Frequency: 1
# Term: year, Frequency: 1
# Term: age, Frequency: 1
# Term: 37, Frequency: 1
# Term: epinao, Frequency: 2
# Term: behind, Frequency: 4
# Term: found, Frequency: 6
# Term: ani, Frequency: 2
# Term: author, Frequency: 3
# Term: coinag, Frequency: 1
# Term: germani, Frequency: 1
# Term: differenti, Frequency: 1
# Term: opisthodomo, Frequency: 1
# Term: parthenon, Frequency: 1
# Term: 38, Frequency: 1
# Term: estípit, Frequency: 1
# Term: churrigueresqu, Frequency: 1
# Term: elabor, Frequency: 1
# Term: taper, Frequency: 3
# Term: estrad, Frequency: 4
# Term: platform, Frequency: 5
# Term: levant, Frequency: 1
# Term: divan, Frequency: 1
# Term: sopha, Frequency: 1
# Term: our, Frequency: 1
# Term: sofa, Frequency: 1
# Term: 39, Frequency: 1
# Term: histor, Frequency: 2
# Term: plant, Frequency: 3
# Term: prune, Frequency: 1
# Term: train, Frequency: 1
# Term: stem, Frequency: 1
# Term: bare, Frequency: 1
# Term: achiev, Frequency: 2
# Term: liken, Frequency: 1
# Term: wed, Frequency: 1
# Term: cake, Frequency: 1
# Term: 40, Frequency: 1
# Term: eustyl, Frequency: 3
# Term: defin, Frequency: 3
# Term: proport, Frequency: 1
# Term: 41, Frequency: 2
# Term: exterior, Frequency: 3
# Term: fanlight, Frequency: 1
# Term: ellipt, Frequency: 1
# Term: glaze, Frequency: 2
# Term: traceri, Frequency: 3
# Term: radiat, Frequency: 1
# Term: fan, Frequency: 3
# Term: conoid, Frequency: 1
# Term: equidist, Frequency: 1
# Term: radial, Frequency: 1
# Term: connect, Frequency: 11
# Term: gothic, Frequency: 5
# Term: fascia, Frequency: 5
# Term: rafter, Frequency: 3
# Term: soffit, Frequency: 7
# Term: help, Frequency: 2
# Term: 42, Frequency: 1
# Term: seen, Frequency: 3
# Term: 43, Frequency: 2
# Term: feretori, Frequency: 2
# Term: enclosur, Frequency: 4
# Term: feret, Frequency: 1
# Term: henri, Frequency: 11
# Term: vii, Frequency: 1
# Term: 44, Frequency: 1
# Term: 46, Frequency: 1
# Term: object, Frequency: 1
# Term: furnitur, Frequency: 1
# Term: pole, Frequency: 1
# Term: fixtur, Frequency: 1
# Term: flushwork, Frequency: 1
# Term: combin, Frequency: 1
# Term: flint, Frequency: 2
# Term: survivor, Frequency: 1
# Term: southern, Frequency: 1
# Term: england, Frequency: 12
# Term: anglia, Frequency: 1
# Term: proudwork, Frequency: 1
# Term: proud, Frequency: 1
# Term: rather, Frequency: 3
# Term: flush, Frequency: 1
# Term: expos, Frequency: 1
# Term: otherwis, Frequency: 1
# Term: highest, Frequency: 1
# Term: skyscrap, Frequency: 1
# Term: foil, Frequency: 1
# Term: symmetr, Frequency: 2
# Term: render, Frequency: 1
# Term: leaf, Frequency: 1
# Term: produc, Frequency: 1
# Term: cusp, Frequency: 2
# Term: lobe, Frequency: 1
# Term: trefoil, Frequency: 2
# Term: quatrefoil, Frequency: 2
# Term: five, Frequency: 1
# Term: cinquefoil, Frequency: 1
# Term: footprint, Frequency: 1
# Term: directli, Frequency: 3
# Term: perimet, Frequency: 1
# Term: 47, Frequency: 1
# Term: stall, Frequency: 3
# Term: translat, Frequency: 1
# Term: 48, Frequency: 1
# Term: formeret, Frequency: 2
# Term: web, Frequency: 8
# Term: 49, Frequency: 1
# Term: fractabl, Frequency: 2
# Term: becom, Frequency: 2
# Term: 50, Frequency: 1
# Term: 51, Frequency: 1
# Term: fusuma, Frequency: 7
# Term: opaqu, Frequency: 2
# Term: cloth, Frequency: 1
# Term: paper, Frequency: 2
# Term: framework, Frequency: 4
# Term: commonli, Frequency: 4
# Term: slide, Frequency: 4
# Term: track, Frequency: 2
# Term: remov, Frequency: 2
# Term: reorgan, Frequency: 2
# Term: reshap, Frequency: 2
# Term: desir, Frequency: 2
# Term: interior, Frequency: 6
# Term: outdoor, Frequency: 3
# Term: paint, Frequency: 1
# Term: graphic, Frequency: 1
# Term: transluc, Frequency: 3
# Term: triangular, Frequency: 5
# Term: gablet, Frequency: 3
# Term: much, Frequency: 1
# Term: period, Frequency: 3
# Term: after, Frequency: 2
# Term: pinnacl, Frequency: 1
# Term: plain, Frequency: 3
# Term: pitch, Frequency: 2
# Term: enrich, Frequency: 2
# Term: crocket, Frequency: 1
# Term: finish, Frequency: 3
# Term: 52, Frequency: 1
# Term: gadroon, Frequency: 1
# Term: invert, Frequency: 1
# Term: popular, Frequency: 1
# Term: dure, Frequency: 1
# Term: italian, Frequency: 1
# Term: 53, Frequency: 1
# Term: gallet, Frequency: 2
# Term: garret, Frequency: 3
# Term: process, Frequency: 1
# Term: splinter, Frequency: 1
# Term: coars, Frequency: 1
# Term: protect, Frequency: 3
# Term: mortar, Frequency: 2
# Term: stuck, Frequency: 1
# Term: wet, Frequency: 1
# Term: 54, Frequency: 1
# Term: gambrel, Frequency: 1
# Term: gargoyl, Frequency: 1
# Term: spout, Frequency: 1
# Term: convey, Frequency: 2
# Term: water, Frequency: 2
# Term: habit, Frequency: 1
# Term: skylight, Frequency: 1
# Term: gaug, Frequency: 1
# Term: rub, Frequency: 2
# Term: soft, Frequency: 1
# Term: gazebo, Frequency: 1
# Term: freestand, Frequency: 3
# Term: pavilion, Frequency: 3
# Term: park, Frequency: 1
# Term: geison, Frequency: 1
# Term: γεῖσον, Frequency: 1
# Term: interchang, Frequency: 1
# Term: ionic, Frequency: 5
# Term: gorgerin, Frequency: 1
# Term: ornat, Frequency: 3
# Term: astragalu, Frequency: 1
# Term: geodes, Frequency: 3
# Term: node, Frequency: 1
# Term: sphere, Frequency: 1
# Term: thereof, Frequency: 1
# Term: pin, Frequency: 2
# Term: geometr, Frequency: 1
# Term: individu, Frequency: 1
# Term: skin, Frequency: 1
# Term: regular, Frequency: 1
# Term: equal, Frequency: 3
# Term: vari, Frequency: 2
# Term: depend, Frequency: 4
# Term: locat, Frequency: 2
# Term: grid, Frequency: 2
# Term: grotto, Frequency: 1
# Term: submerg, Frequency: 1
# Term: landscap, Frequency: 2
# Term: art, Frequency: 6
# Term: no, Frequency: 2
# Term: exit, Frequency: 2
# Term: enter, Frequency: 2
# Term: gutta, Frequency: 2
# Term: drop, Frequency: 1
# Term: triglyph, Frequency: 7
# Term: taenia, Frequency: 3
# Term: well, Frequency: 1
# Term: mutul, Frequency: 4
# Term: hip, Frequency: 2
# Term: downward, Frequency: 1
# Term: hood, Frequency: 2
# Term: throw, Frequency: 1
# Term: rainwat, Frequency: 1
# Term: dripston, Frequency: 1
# Term: hyphen, Frequency: 4
# Term: possibl, Frequency: 2
# Term: older, Frequency: 1
# Term: heifunon, Frequency: 4
# Term: 55, Frequency: 1
# Term: imperi, Frequency: 1
# Term: union, Frequency: 1
# Term: offici, Frequency: 1
# Term: anoth, Frequency: 3
# Term: 56, Frequency: 2
# Term: regularli, Frequency: 1
# Term: six, Frequency: 3
# Term: pycnostyl, Frequency: 3
# Term: systyl, Frequency: 3
# Term: interlac, Frequency: 3
# Term: scheme, Frequency: 1
# Term: romanesqu, Frequency: 4
# Term: thrown, Frequency: 1
# Term: former, Frequency: 1
# Term: first, Frequency: 2
# Term: second, Frequency: 2
# Term: actual, Frequency: 1
# Term: 57, Frequency: 1
# Term: volut, Frequency: 2
# Term: jagati, Frequency: 1
# Term: techniqu, Frequency: 1
# Term: timber, Frequency: 5
# Term: dimens, Frequency: 1
# Term: kamoi, Frequency: 1
# Term: 58, Frequency: 2
# Term: katsuogi, Frequency: 3
# Term: atop, Frequency: 1
# Term: normal, Frequency: 1
# Term: current, Frequency: 1
# Term: pariti, Frequency: 1
# Term: crown, Frequency: 3
# Term: lock, Frequency: 1
# Term: posit, Frequency: 2
# Term: adorn, Frequency: 1
# Term: pattern, Frequency: 6
# Term: recess, Frequency: 4
# Term: 59, Frequency: 1
# Term: latticework, Frequency: 1
# Term: lattic, Frequency: 2
# Term: strip, Frequency: 2
# Term: criss, Frequency: 1
# Term: lesen, Frequency: 2
# Term: 60, Frequency: 1
# Term: mullion, Frequency: 3
# Term: muntin, Frequency: 2
# Term: sash, Frequency: 4
# Term: lightn, Frequency: 2
# Term: rod, Frequency: 2
# Term: conduct, Frequency: 2
# Term: copper, Frequency: 2
# Term: zinc, Frequency: 1
# Term: coat, Frequency: 1
# Term: conductor, Frequency: 1
# Term: earth, Frequency: 1
# Term: safe, Frequency: 1
# Term: electr, Frequency: 2
# Term: charg, Frequency: 1
# Term: caus, Frequency: 1
# Term: strike, Frequency: 2
# Term: avoid, Frequency: 1
# Term: damag, Frequency: 1
# Term: fire, Frequency: 1
# Term: loculu, Frequency: 1
# Term: nich, Frequency: 3
# Term: catacomb, Frequency: 2
# Term: hypogeum, Frequency: 1
# Term: mausoleum, Frequency: 1
# Term: entomb, Frequency: 1
# Term: loggia, Frequency: 1
# Term: galleri, Frequency: 1
# Term: overlook, Frequency: 1
# Term: lunett, Frequency: 1
# Term: moon, Frequency: 1
# Term: void, Frequency: 2
# Term: mandapa, Frequency: 1
# Term: ritual, Frequency: 1
# Term: maqsurah, Frequency: 1
# Term: maqsura, Frequency: 1
# Term: pray, Frequency: 1
# Term: mansard, Frequency: 2
# Term: curb, Frequency: 1
# Term: steeper, Frequency: 1
# Term: accomplish, Frequency: 1
# Term: 17th, Frequency: 1
# Term: invent, Frequency: 1
# Term: françoi, Frequency: 1
# Term: mansart, Frequency: 1
# Term: die, Frequency: 1
# Term: 1666, Frequency: 1
# Term: marriag, Frequency: 2
# Term: date, Frequency: 2
# Term: mascaron, Frequency: 1
# Term: human, Frequency: 2
# Term: frighten, Frequency: 1
# Term: chimer, Frequency: 1
# Term: meander, Frequency: 1
# Term: border, Frequency: 1
# Term: repeat, Frequency: 1
# Term: 61, Frequency: 1
# Term: fret, Frequency: 2
# Term: key, Frequency: 1
# Term: metop, Frequency: 3
# Term: 62, Frequency: 2
# Term: these, Frequency: 2
# Term: 63, Frequency: 1
# Term: mihrab, Frequency: 1
# Term: minaret, Frequency: 1
# Term: tall, Frequency: 2
# Term: spire, Frequency: 2
# Term: conic, Frequency: 2
# Term: onion, Frequency: 3
# Term: modillion, Frequency: 3
# Term: bedmould, Frequency: 1
# Term: probabl, Frequency: 3
# Term: becaus, Frequency: 2
# Term: arrang, Frequency: 3
# Term: regul, Frequency: 1
# Term: 64, Frequency: 1
# Term: monotriglyph, Frequency: 2
# Term: observ, Frequency: 1
# Term: intervent, Frequency: 1
# Term: axe, Frequency: 1
# Term: propylaea, Frequency: 1
# Term: there, Frequency: 4
# Term: increas, Frequency: 2
# Term: roadway, Frequency: 1
# Term: chariot, Frequency: 1
# Term: beast, Frequency: 1
# Term: sacrific, Frequency: 1
# Term: ascend, Frequency: 1
# Term: 65, Frequency: 1
# Term: cp, Frequency: 2
# Term: transom, Frequency: 2
# Term: pane, Frequency: 2
# Term: lite, Frequency: 1
# Term: muqarna, Frequency: 1
# Term: circumst, Frequency: 1
# Term: stalactit, Frequency: 1
# Term: stud, Frequency: 1
# Term: suppos, Frequency: 2
# Term: repres, Frequency: 1
# Term: peg, Frequency: 2
# Term: hold, Frequency: 1
# Term: rake, Frequency: 4
# Term: virtual, Frequency: 1
# Term: fulfil, Frequency: 1
# Term: 66, Frequency: 1
# Term: narthex, Frequency: 1
# Term: congreg, Frequency: 1
# Term: approach, Frequency: 1
# Term: high, Frequency: 4
# Term: newel, Frequency: 1
# Term: upright, Frequency: 3
# Term: stair, Frequency: 2
# Term: intermedi, Frequency: 1
# Term: terminu, Frequency: 3
# Term: land, Frequency: 1
# Term: exedra, Frequency: 1
# Term: been, Frequency: 3
# Term: reduc, Frequency: 1
# Term: retain, Frequency: 1
# Term: oculu, Frequency: 1
# Term: pantheon, Frequency: 1
# Term: oillet, Frequency: 2
# Term: slit, Frequency: 1
# Term: strictli, Frequency: 1
# Term: hole, Frequency: 1
# Term: 67, Frequency: 1
# Term: standard, Frequency: 1
# Term: western, Frequency: 2
# Term: orthost, Frequency: 1
# Term: ὀρθοστάτης, Frequency: 1
# Term: nao, Frequency: 3
# Term: marbl, Frequency: 1
# Term: constitut, Frequency: 1
# Term: 68, Frequency: 1
# Term: orthostyl, Frequency: 2
# Term: ὃρθος, Frequency: 1
# Term: στῦλος, Frequency: 1
# Term: instanc, Frequency: 1
# Term: 69, Frequency: 1
# Term: ellips, Frequency: 1
# Term: 70, Frequency: 1
# Term: parclos, Frequency: 3
# Term: 1530, Frequency: 1
# Term: moorhay, Frequency: 1
# Term: cullompton, Frequency: 1
# Term: devon, Frequency: 1
# Term: millwork, Frequency: 1
# Term: rigid, Frequency: 2
# Term: compon, Frequency: 2
# Term: could, Frequency: 1
# Term: plastic, Frequency: 1
# Term: materi, Frequency: 1
# Term: antiqu, Frequency: 1
# Term: comfort, Frequency: 1
# Term: insul, Frequency: 1
# Term: cold, Frequency: 1
# Term: instal, Frequency: 1
# Term: wainscot, Frequency: 1
# Term: boiseri, Frequency: 1
# Term: particular, Frequency: 1
# Term: extrem, Frequency: 1
# Term: associ, Frequency: 2
# Term: seventeenth, Frequency: 1
# Term: eighteenth, Frequency: 1
# Term: victorian, Frequency: 1
# Term: britain, Frequency: 1
# Term: contemporari, Frequency: 1
# Term: against, Frequency: 1
# Term: fall, Frequency: 1
# Term: bridg, Frequency: 3
# Term: 71, Frequency: 1
# Term: chantri, Frequency: 1
# Term: manori, Frequency: 1
# Term: thu, Frequency: 2
# Term: 72, Frequency: 1
# Term: parterr, Frequency: 2
# Term: mostli, Frequency: 1
# Term: bed, Frequency: 1
# Term: hedg, Frequency: 1
# Term: interwoven, Frequency: 1
# Term: gravel, Frequency: 1
# Term: grass, Frequency: 1
# Term: path, Frequency: 1
# Term: meant, Frequency: 1
# Term: denser, Frequency: 1
# Term: taller, Frequency: 1
# Term: plinth, Frequency: 4
# Term: statu, Frequency: 3
# Term: obelisk, Frequency: 1
# Term: trim, Frequency: 4
# Term: thicker, Frequency: 2
# Term: wider, Frequency: 3
# Term: gr, Frequency: 1
# Term: ἀετός, Frequency: 1
# Term: lat, Frequency: 1
# Term: fastigium, Frequency: 1
# Term: fr, Frequency: 1
# Term: ponton, Frequency: 1
# Term: tympanum, Frequency: 2
# Term: pelmet, Frequency: 1
# Term: pendent, Frequency: 1
# Term: dimension, Frequency: 1
# Term: spandrel, Frequency: 2
# Term: peripter, Frequency: 3
# Term: continu, Frequency: 3
# Term: whether, Frequency: 1
# Term: peristasi, Frequency: 2
# Term: περίστασις, Frequency: 1
# Term: periptero, Frequency: 1
# Term: ecclesi, Frequency: 2
# Term: cathol, Frequency: 1
# Term: courtyard, Frequency: 1
# Term: cloister, Frequency: 1
# Term: phial, Frequency: 1
# Term: fountain, Frequency: 1
# Term: 73, Frequency: 1
# Term: do, Frequency: 1
# Term: 74, Frequency: 1
# Term: planceer, Frequency: 2
# Term: planchier, Frequency: 1
# Term: sens, Frequency: 2
# Term: correctli, Frequency: 1
# Term: corona, Frequency: 1
# Term: 75, Frequency: 1
# Term: plate, Frequency: 3
# Term: flang, Frequency: 1
# Term: weld, Frequency: 1
# Term: bolt, Frequency: 1
# Term: rivet, Frequency: 1
# Term: stiffen, Frequency: 1
# Term: poppyhead, Frequency: 1
# Term: pew, Frequency: 1
# Term: richli, Frequency: 1
# Term: imag, Frequency: 1
# Term: knot, Frequency: 1
# Term: foliag, Frequency: 1
# Term: fleur, Frequency: 1
# Term: de, Frequency: 1
# Term: li, Frequency: 1
# Term: simpli, Frequency: 1
# Term: thick, Frequency: 1
# Term: deriv, Frequency: 1
# Term: poupe, Frequency: 1
# Term: doll, Frequency: 1
# Term: puppet, Frequency: 1
# Term: 76, Frequency: 1
# Term: portculli, Frequency: 1
# Term: gateway, Frequency: 1
# Term: castl, Frequency: 3
# Term: port, Frequency: 1
# Term: cochèr, Frequency: 1
# Term: secondari, Frequency: 1
# Term: vehicl, Frequency: 1
# Term: pass, Frequency: 1
# Term: occup, Frequency: 1
# Term: alight, Frequency: 1
# Term: prick, Frequency: 2
# Term: old, Frequency: 1
# Term: name, Frequency: 4
# Term: queen, Frequency: 1
# Term: 77, Frequency: 1
# Term: prostyl, Frequency: 1
# Term: apart, Frequency: 2
# Term: adject, Frequency: 1
# Term: pseudodipter, Frequency: 1
# Term: dipter, Frequency: 2
# Term: agrigentum, Frequency: 1
# Term: celia, Frequency: 1
# Term: rear, Frequency: 3
# Term: isol, Frequency: 1
# Term: 78, Frequency: 1
# Term: pteroma, Frequency: 1
# Term: stoa, Frequency: 1
# Term: 79, Frequency: 1
# Term: quadriporticu, Frequency: 1
# Term: quadriportico, Frequency: 1
# Term: closest, Frequency: 1
# Term: would, Frequency: 1
# Term: quadrangl, Frequency: 1
# Term: quirk, Frequency: 2
# Term: 80, Frequency: 1
# Term: cornerston, Frequency: 1
# Term: express, Frequency: 1
# Term: equival, Frequency: 1
# Term: ratio, Frequency: 1
# Term: splay, Frequency: 3
# Term: reveal, Frequency: 1
# Term: scoinson, Frequency: 2
# Term: further, Frequency: 1
# Term: 81, Frequency: 1
# Term: ressaut, Frequency: 1
# Term: signboard, Frequency: 1
# Term: revolv, Frequency: 2
# Term: exclud, Frequency: 1
# Term: draft, Frequency: 1
# Term: hang, Frequency: 1
# Term: rotat, Frequency: 1
# Term: comb, Frequency: 1
# Term: pyramid, Frequency: 3
# Term: mesoamerican, Frequency: 1
# Term: america, Frequency: 1
# Term: 19th, Frequency: 2
# Term: rotunda, Frequency: 1
# Term: alway, Frequency: 1
# Term: surmount, Frequency: 1
# Term: fix, Frequency: 3
# Term: oper, Frequency: 3
# Term: differ, Frequency: 2
# Term: awn, Frequency: 1
# Term: hopper, Frequency: 1
# Term: spere, Frequency: 2
# Term: sequenc, Frequency: 1
# Term: heart, Frequency: 1
# Term: among, Frequency: 1
# Term: foliat, Frequency: 1
# Term: vine, Frequency: 1
# Term: shiki, Frequency: 1
# Term: diffus, Frequency: 1
# Term: sound, Frequency: 1
# Term: site, Frequency: 2
# Term: specif, Frequency: 1
# Term: time, Frequency: 1
# Term: respond, Frequency: 1
# Term: both, Frequency: 1
# Term: physic, Frequency: 2
# Term: context, Frequency: 2
# Term: metaphys, Frequency: 1
# Term: conceiv, Frequency: 1
# Term: execut, Frequency: 1
# Term: skeil, Frequency: 2
# Term: undersid, Frequency: 2
# Term: 82, Frequency: 2
# Term: sommer, Frequency: 2
# Term: summer, Frequency: 3
# Term: bress, Frequency: 1
# Term: centerlin, Frequency: 1
# Term: joist, Frequency: 1
# Term: 83, Frequency: 1
# Term: sill, Frequency: 1
# Term: slant, Frequency: 1
# Term: insid, Frequency: 1
# Term: 84, Frequency: 1
# Term: voussoir, Frequency: 2
# Term: squinch, Frequency: 1
# Term: proper, Frequency: 1
# Term: receiv, Frequency: 1
# Term: spheric, Frequency: 1
# Term: squint, Frequency: 1
# Term: view, Frequency: 2
# Term: stoop, Frequency: 1
# Term: sunburst, Frequency: 1
# Term: nouveau, Frequency: 1
# Term: syrian, Frequency: 2
# Term: esp, Frequency: 1
# Term: richardsonian, Frequency: 2
# Term: archway, Frequency: 1
# Term: begin, Frequency: 1
# Term: thickli, Frequency: 1
# Term: assign, Frequency: 1
# Term: 85, Frequency: 1
# Term: 86, Frequency: 1
# Term: throat, Frequency: 1
# Term: underneath, Frequency: 1
# Term: prevent, Frequency: 1
# Term: back, Frequency: 1
# Term: onto, Frequency: 1
# Term: mortis, Frequency: 1
# Term: tenon, Frequency: 1
# Term: trabeat, Frequency: 1
# Term: simpl, Frequency: 1
# Term: stonework, Frequency: 1
# Term: 87, Frequency: 1
# Term: truss, Frequency: 3
# Term: chord, Frequency: 2
# Term: τύμπανον, Frequency: 1
# Term: τύπτειν, Frequency: 1
# Term: undercroft, Frequency: 1
# Term: cellar, Frequency: 1
# Term: storag, Frequency: 1
# Term: usag, Frequency: 1
# Term: rel, Frequency: 1
# Term: permit, Frequency: 1
# Term: vierendeel, Frequency: 1
# Term: rectilinear, Frequency: 1
# Term: fabric, Frequency: 1
# Term: basi, Frequency: 1
# Term: 88, Frequency: 1
# Term: widow, Frequency: 1
# Term: walk, Frequency: 1
# Term: rooftop, Frequency: 1
# Term: frequent, Frequency: 1
# Term: north, Frequency: 1
# Term: coastal, Frequency: 1
# Term: zaguan, Frequency: 1
# Term: complex, Frequency: 1
# Term: whole, Frequency: 1
# Term: territori, Frequency: 2
# Term: southwest, Frequency: 1
# Term: ziggurat, Frequency: 1
# Term: mesopotamian, Frequency: 1
# Term: valley, Frequency: 1
# Term: look, Frequency: 3
# Term: appendix, Frequency: 1
# Term: wiktionari, Frequency: 1
# Term: dictionari, Frequency: 11
# Term: portal, Frequency: 1
# Term: outlin, Frequency: 1
# Term: merriam, Frequency: 1
# Term: webster, Frequency: 1
# Term: retriev, Frequency: 11
# Term: 2022, Frequency: 6
# Term: preced, Frequency: 1
# Term: sentenc, Frequency: 1
# Term: incorpor, Frequency: 4
# Term: text, Frequency: 3
# Term: domain, Frequency: 1
# Term: chisholm, Frequency: 1
# Term: hugh, Frequency: 1
# Term: ed, Frequency: 76
# Term: 1911, Frequency: 51
# Term: encyclopædia, Frequency: 50
# Term: britannica, Frequency: 50
# Term: vol, Frequency: 28
# Term: 11th, Frequency: 48
# Term: cambridg, Frequency: 1
# Term: univers, Frequency: 6
# Term: press, Frequency: 3
# Term: 509, Frequency: 1
# Term: ephraim, Frequency: 3
# Term: 1728, Frequency: 4
# Term: cyclopædia, Frequency: 3
# Term: scienc, Frequency: 6
# Term: 1st, Frequency: 3
# Term: jame, Frequency: 5
# Term: john, Frequency: 14
# Term: knapton, Frequency: 3
# Term: et, Frequency: 3
# Term: al, Frequency: 3
# Term: 269, Frequency: 2
# Term: 557, Frequency: 1
# Term: parker, Frequency: 10
# Term: 1994, Frequency: 10
# Term: concis, Frequency: 10
# Term: 9th, Frequency: 10
# Term: london, Frequency: 10
# Term: studio, Frequency: 10
# Term: ltd, Frequency: 10
# Term: isbn, Frequency: 20
# Term: 1859580696, Frequency: 10
# Term: 804, Frequency: 1
# Term: fletcher, Frequency: 16
# Term: banist, Frequency: 16
# Term: 1975, Frequency: 8
# Term: sir, Frequency: 8
# Term: 18th, Frequency: 8
# Term: new, Frequency: 9
# Term: york, Frequency: 9
# Term: citi, Frequency: 8
# Term: charl, Frequency: 8
# Term: scribner, Frequency: 8
# Term: son, Frequency: 9
# Term: 1315, Frequency: 1
# Term: 0684142074, Frequency: 8
# Term: 273, Frequency: 1
# Term: 371, Frequency: 1
# Term: cinqu, Frequency: 1
# Term: cento, Frequency: 1
# Term: 377, Frequency: 1
# Term: 379, Frequency: 1
# Term: 481, Frequency: 1
# Term: ching, Frequency: 2
# Term: 1995, Frequency: 2
# Term: 811, Frequency: 1
# Term: pp, Frequency: 3
# Term: 1316, Frequency: 1
# Term: 510, Frequency: 1
# Term: 566, Frequency: 1
# Term: 91, Frequency: 1
# Term: 706, Frequency: 1
# Term: access, Frequency: 1
# Term: decemb, Frequency: 2
# Term: 2019, Frequency: 2
# Term: diazomata, Frequency: 1
# Term: heritag, Frequency: 1
# Term: onlin, Frequency: 1
# Term: thesauru, Frequency: 1
# Term: 2016, Frequency: 1
# Term: deurer, Frequency: 2
# Term: 2011, Frequency: 2
# Term: catacoomb, Frequency: 1
# Term: societi, Frequency: 1
# Term: archiv, Frequency: 6
# Term: 2006, Frequency: 3
# Term: 01, Frequency: 2
# Term: 669, Frequency: 1
# Term: 800, Frequency: 1
# Term: met, Frequency: 1
# Term: blog, Frequency: 1
# Term: 2009, Frequency: 2
# Term: 957, Frequency: 1
# Term: bonk, Frequency: 1
# Term: lawrenc, Frequency: 1
# Term: understand, Frequency: 1
# Term: repair, Frequency: 1
# Term: angi, Frequency: 1
# Term: 115, Frequency: 1
# Term: 1319, Frequency: 1
# Term: harri, Frequency: 1
# Term: cyril, Frequency: 1
# Term: 4th, Frequency: 1
# Term: mcgraw, Frequency: 1
# Term: hill, Frequency: 1
# Term: ny, Frequency: 1
# Term: 628, Frequency: 1
# Term: collinsdictionari, Frequency: 1
# Term: com, Frequency: 4
# Term: harpercollin, Frequency: 1
# Term: curl, Frequency: 1
# Term: steven, Frequency: 1
# Term: wilson, Frequency: 1
# Term: susan, Frequency: 1
# Term: 2015, Frequency: 1
# Term: 3rd, Frequency: 1
# Term: oxford, Frequency: 4
# Term: 9780199674985, Frequency: 1
# Term: cite, Frequency: 1
# Term: book, Frequency: 1
# Term: cs1, Frequency: 1
# Term: maint, Frequency: 2
# Term: multipl, Frequency: 2
# Term: 381, Frequency: 1
# Term: godroon, Frequency: 1
# Term: 475, Frequency: 1
# Term: richard, Frequency: 1
# Term: taylor, Frequency: 1
# Term: aia, Frequency: 1
# Term: april, Frequency: 1
# Term: 2007, Frequency: 2
# Term: about, Frequency: 5
# Term: expert, Frequency: 1
# Term: own, Frequency: 1
# Term: octob, Frequency: 2
# Term: 2008, Frequency: 2
# Term: juli, Frequency: 3
# Term: question, Frequency: 1
# Term: film, Frequency: 1
# Term: sight, Frequency: 1
# Term: mention, Frequency: 1
# Term: realli, Frequency: 1
# Term: find, Frequency: 1
# Term: noth, Frequency: 1
# Term: spell, Frequency: 1
# Term: answer, Frequency: 1
# Term: my, Frequency: 1
# Term: guess, Frequency: 1
# Term: re, Frequency: 1
# Term: talk, Frequency: 1
# Term: mass, Frequency: 2
# Term: coloni, Frequency: 1
# Term: era, Frequency: 1
# Term: photo, Frequency: 1
# Term: brice, Frequency: 1
# Term: clearli, Frequency: 1
# Term: visibl, Frequency: 1
# Term: url, Frequency: 2
# Term: dead, Frequency: 1
# Term: http, Frequency: 3
# Term: org, Frequency: 2
# Term: 20081012052215, Frequency: 1
# Term: en, Frequency: 2
# Term: allexpert, Frequency: 1
# Term: 2369, Frequency: 1
# Term: htm, Frequency: 1
# Term: 141, Frequency: 1
# Term: 693, Frequency: 1
# Term: takashi, Frequency: 1
# Term: sasaki, Frequency: 1
# Term: june, Frequency: 1
# Term: 2021, Frequency: 2
# Term: basic, Frequency: 1
# Term: residenti, Frequency: 1
# Term: meguri, Frequency: 1
# Term: japan, Frequency: 1
# Term: 1322, Frequency: 1
# Term: 124, Frequency: 1
# Term: 1323, Frequency: 1
# Term: 155, Frequency: 1
# Term: 156, Frequency: 1
# Term: 102, Frequency: 1
# Term: orthostata, Frequency: 1
# Term: 183, Frequency: 1
# Term: oxforddictionari, Frequency: 1
# Term: 1912, Frequency: 1
# Term: 04, Frequency: 1
# Term: 2012, Frequency: 1
# Term: 2014, Frequency: 1
# Term: 05, Frequency: 3
# Term: 1325, Frequency: 1
# Term: craven, Frequency: 1
# Term: jacki, Frequency: 1
# Term: 2018, Frequency: 1
# Term: 08, Frequency: 1
# Term: thoughtco, Frequency: 1
# Term: 713, Frequency: 1
# Term: poppi, Frequency: 1
# Term: pseudo, Frequency: 1
# Term: 541, Frequency: 1
# Term: 542, Frequency: 1
# Term: 1327, Frequency: 1
# Term: march, Frequency: 1
# Term: 393, Frequency: 1
# Term: 263, Frequency: 1
# Term: 1329, Frequency: 1
# Term: 309, Frequency: 1
# Term: def, Frequency: 1
# Term: cd, Frequency: 1
# Term: rom, Frequency: 1
# Term: 0, Frequency: 4
# Term: franci, Frequency: 1
# Term: visual, Frequency: 1
# Term: wiley, Frequency: 1
# Term: 471, Frequency: 1
# Term: 28451, Frequency: 1
# Term: egyptian, Frequency: 1
# Term: mytholog, Frequency: 1
# Term: wikisourc, Frequency: 2
# Term: box, Frequency: 1
# Term: vteglossari, Frequency: 1
# Term: aerospac, Frequency: 1
# Term: agricultur, Frequency: 1
# Term: archaeolog, Frequency: 1
# Term: artifici, Frequency: 1
# Term: intellig, Frequency: 1
# Term: astronomi, Frequency: 1
# Term: biolog, Frequency: 5
# Term: botani, Frequency: 1
# Term: calculu, Frequency: 1
# Term: cell, Frequency: 1
# Term: chemistri, Frequency: 1
# Term: civil, Frequency: 1
# Term: clinic, Frequency: 1
# Term: research, Frequency: 1
# Term: comput, Frequency: 3
# Term: hardwar, Frequency: 1
# Term: development, Frequency: 1
# Term: reproduct, Frequency: 1
# Term: ecolog, Frequency: 1
# Term: econom, Frequency: 1
# Term: electron, Frequency: 1
# Term: entomolog, Frequency: 1
# Term: environment, Frequency: 1
# Term: genet, Frequency: 1
# Term: evolutionari, Frequency: 1
# Term: cellular, Frequency: 1
# Term: molecular, Frequency: 1
# Term: geographi, Frequency: 1
# Term: arab, Frequency: 1
# Term: toponym, Frequency: 2
# Term: hebrew, Frequency: 1
# Term: asia, Frequency: 1
# Term: geolog, Frequency: 1
# Term: ichthyolog, Frequency: 1
# Term: machin, Frequency: 1
# Term: vision, Frequency: 1
# Term: mathemat, Frequency: 1
# Term: mechan, Frequency: 1
# Term: medicin, Frequency: 1
# Term: meteorolog, Frequency: 1
# Term: mycolog, Frequency: 1
# Term: nanotechnolog, Frequency: 1
# Term: ornitholog, Frequency: 1
# Term: statist, Frequency: 2
# Term: psychiatri, Frequency: 1
# Term: quantum, Frequency: 1
# Term: robot, Frequency: 1
# Term: scientif, Frequency: 1
# Term: virolog, Frequency: 1
# Term: index, Frequency: 1
# Term: php, Frequency: 1
# Term: titl, Frequency: 1
# Term: glossary_of_architectur, Frequency: 1
# Term: oldid, Frequency: 1
# Term: 1236153144, Frequency: 1
# Term: categori, Frequency: 2
# Term: engineeringglossari, Frequency: 1
# Term: artsglossari, Frequency: 1
# Term: sciencearchitectur, Frequency: 1
# Term: listsarchitectur, Frequency: 1
# Term: elementsvisu, Frequency: 1
# Term: terminologyhidden, Frequency: 1
# Term: articl, Frequency: 3
# Term: citat, Frequency: 2
# Term: encyclopaedia, Frequency: 1
# Term: referencewikipedia, Frequency: 1
# Term: britannicawikipedia, Frequency: 1
# Term: cyclopaediacs1, Frequency: 1
# Term: listarticl, Frequency: 1
# Term: descriptionshort, Frequency: 1
# Term: descript, Frequency: 2
# Term: wikidataarticl, Frequency: 1
# Term: 1453, Frequency: 1
# Term: textwikipedia, Frequency: 1
# Term: last, Frequency: 1
# Term: 2024, Frequency: 1
# Term: utc, Frequency: 1
# Term: avail, Frequency: 1
# Term: creativ, Frequency: 1
# Term: attribut, Frequency: 1
# Term: sharealik, Frequency: 1
# Term: licens, Frequency: 1
# Term: you, Frequency: 1
# Term: agre, Frequency: 1
# Term: privaci, Frequency: 2
# Term: polici, Frequency: 2
# Term: regist, Frequency: 1
# Term: trademark, Frequency: 1
# Term: wikimedia, Frequency: 1
# Term: foundat, Frequency: 1
# Term: inc, Frequency: 1
# Term: non, Frequency: 1
# Term: profit, Frequency: 1
# Term: organ, Frequency: 1
# Term: disclaim, Frequency: 1
# Term: contact, Frequency: 1
# Term: code, Frequency: 1
# Term: cooki, Frequency: 1
# Term: statement, Frequency: 1
# Term: mobil, Frequency: 1
# Indexed data has been saved to Firebase.
